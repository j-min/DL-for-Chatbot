# %% [markdown]
# # Reference
# - https://www.lucypark.kr/courses/2015-ba/text-mining.html#topic-modeling

# %% [markdown]
# # Load Data

# %%
from konlpy.corpus import kobill
file_ids = kobill.fileids()
file_ids
# Out:
# ['1809890.txt',
#  '1809891.txt',
#  '1809892.txt',
#  '1809893.txt',
#  '1809894.txt',
#  '1809895.txt',
#  '1809896.txt',
#  '1809897.txt',
#  '1809898.txt',
#  '1809899.txt']

# %%
doc = " ".join([kobill.open(i).read() for i in file_ids])

# %%
doc
# Out:
# '지방공무원법 일부개정법률안\n\n(정의화의원 대표발의 )\n\n 의 안\n 번 호\n\n9890\n\n발의연월일 : 2010.  11.  12.  \n\n발  의  자 : 정의화․이명수․김을동 \n\n이사철․여상규․안규백\n\n황영철․박영아․김정훈\n\n김학송 의원(10인)\n\n제안이유 및 주요내용\n\n  초등학교 저학년의 경우에도 부모의 따뜻한 사랑과 보살핌이 필요\n\n한 나이이나, 현재 공무원이 자녀를 양육하기 위하여 육아휴직을 할 \n\n수 있는 자녀의 나이는 만 6세 이하로 되어 있어 초등학교 저학년인 \n\n자녀를 돌보기 위해서는 해당 부모님은 일자리를 그만 두어야 하고 \n\n이는 곧 출산의욕을 저하시키는 문제로 이어질 수 있을 것임.\n\n  따라서 육아휴직이 가능한 자녀의 연령을 만 8세 이하로 개정하려\n\n는 것임(안 제63조제2항제4호).\n\n- 1 -\n\n\x0c법률  제        호\n\n지방공무원법 일부개정법률안\n\n지방공무원법 일부를 다음과 같이 개정한다.\n\n제63조제2항제4호 중 “만 6세 이하의 초등학교 취학 전 자녀를”을 “만 \n\n8세 이하(취학 중인 경우에는 초등학교 2학년 이하를 말한다)의 자녀를”\n\n로 한다.\n\n부      칙\n\n이 법은 공포한 날부터 시행한다.\n\n- 3 -\n\n\x0c신 ·구조문대비표\n\n현      행\n\n개   정   안\n\n제63조(휴직) ① (생  략)\n\n제63조(휴직) ① (현행과 같음)\n\n  ② 공무원이 다음 각 호의 어\n\n  ② -------------------------\n\n느 하나에 해당하는 사유로 휴\n\n----------------------------\n\n직을 원하면 임용권자는 휴직\n\n----------------------------\n\n을 명할 수 있다. 다만, 제4호\n\n-------------.---------------\n\n의 경우에는 대통령령으로 정\n\n----------------------------\n\n하는 특별한 사정이 없으면 휴\n\n----------------------------\n\n직을 명하여야 한다.\n\n--------------.\n\n  1. ∼ 3. (생  략)\n\n  1. ∼ 3. (현행과 같음)\n\n  4. 만 6세 이하의 초등학교 취\n\n  4. 만 8세 이하(취학 중인 경우\n\n학 전 자녀를 양육하기 위하\n\n에는 초등학교 2학년 이하를 \n\n여 필요하거나 여자공무원이 \n\n말한다)의 자녀를 ----------\n\n임신 또는 출산하게 되었을 \n\n---------------------------\n\n때\n\n---------------------------\n\n  5.⋅6. (생  략)\n\n  ③⋅④ (생  략)\n\n--------\n\n  5.⋅6. (현행과 같음)\n\n  ③⋅④ (현행과 같음)\n\n- 5 -\n\n\x0c지방공무원법 일부개정법률안 등 비용추계서 미첨부사유서\n1.  재정수반요인\n\n개정안에서 ｢국가공무원법｣  제71조제2항제4호 중 국가공무원의 육아\n\n휴직 가능 자녀의 연령을 만6세 이하에서 만8세 이하로 하고, ｢지방공\n\n무원법｣ 제63조제2항제4호 중 지방공무원의 육아휴직 가능 자녀의 연\n\n령을 만6세 이하에서 만8세 이하로 하고, ｢교육공무원법｣ 제44조제1항\n\n제7조 중 교육공무원의 육아휴직 가능 자녀의 연령을 만6세 이하에서 \n\n만8세 이하로 하고, ｢남녀고용평등과 일․가정 양립지원에 관한 법률｣ \n\n제19조제1항 중 근로자 육아휴직 가능 자녀연령을 만6세 이하에서 만\n\n8세 이하로 조정함에 따라 추가 재정소요가 예상됨.\n\n2.  미첨부  근거  규정\n｢의안의 비용추계에 관한 규칙｣ 제3조제1항 단서 중 제1호(예상되는 비용이 연평균  10억원 미만\n이거나  한시적인  경비로서  총  30억원  미만인  경우)에  해당함.\n\n3.  미첨부  사유\n\n개정안에서 국가․지방․교육공무원 및 근로자가 육아휴직을 신청할 \n\n수 있는 자녀의 연령을 만6세 이하에서 만8세 이하로 상향조정함에 \n\n따라 추가 재정소요가 예상된다. 동 법률 개정안이 2011년에 시행된다\n\n고 가정한 경우, 2010년 현재 자녀의 연령이 7세이고 육아휴직을 신청\n\n- 7 -\n\n\x0c- 8 -\n\n하지 않은 국가․지방․교육공무원 및 근로자가 대상이 된다.\n\n대상연령의 확대됨에 따라 육아휴직신청자의 수가 어느 정도 늘어날 \n\n것으로 예상된다. 이 경우 발생하는 비용은 현행법에 따르면 월50만원\n\n이나 현재 관련법령 개정이 추진되고 있으며, 이에 따라 2011년에는 \n\n육아휴직자가 지급받는 월급여액에 비례하여 육아휴직급여가 지급되\n\n기 때문에 법령개정을 가정하고 추계한다. 이러한 경우 육아휴직급여\n\n액은 육아휴직자가 지급받는 월급여의 40%에 해당한다. 육아휴직자가 \n\n발생한 경우 발생하는 비용은 대체인력 고용인건비와 육아휴직자가 \n\n받는 월급여액의 40%이다. 이와 대비하여 육아휴직자에게 지급하던 \n\n임금은 더 이상 발생하지 않는다. 따라서 실제 발생하는 순비용은 육\n\n아휴직자에게 지급하던 월 급여액과 연령 확대에 따라 발생하는 비용\n\n인 육아휴직자가 받던 월급여액의 40%와 대체인력 고용인건비의 차\n\n액인데 이 값이 0보다 크면 추가 재정소요는 발생하지 않는다고 볼 \n\n수 있다.\n\n추가비용 발생여부를 정확하게 알아보기 위하여 비용에 대한 수리모\n\n델을 만들고 이에 따라 비용발생 여부를 알아보기로 하자. 모델에 사\n\n용되는 변수를 다음과 같이 정의한다.\n\n발생비용 : N×p×X + N×육아휴직급여액 - N×P\n\nN\n\nP\n\n: 육아휴직대상자의 수\n\n: 육아휴직대상자의 월급여액\n\n\x0cp\n\nX\n\n: 육아휴직자가 발생한 경우 대체 고용할 확률\n\n: 대체 고용한 인력에게 지급하는 월급여액\n\n위의 수식에서 육아휴직급여액은 육아휴직자 월급여액의 40%까지 지\n\n급할 예정이므로 육아휴직급여액은 P×40%이다. 육아휴직자가 발생한 \n\n경우 대체 고용할 확률 p는 고용노동부의 육아휴직 관련 자료를 이용\n\n한다. 고용노동부에 따르면 2011년의 경우 육아휴직급여 대상자는 \n\n40,923명이며, 육아휴직에 따른 대체인력 고용 예상인원은 2,836명이\n\n다. 2007년부터 2011년까지의 현황을 정리하면 다음의 [표]와 같다.\n\n[표]  육아휴직급여  수급자의  수  및  대체인력  고용  현황:  2007~2011년\n\n(단위:  명,  % )\n\n2007\n\n2008\n\n2009\n\n2010\n\n2011\n\n평균\n\n육아휴직급여  수급자(A)\n\n21,185\n\n29,145\n\n35,400\n\n41,291\n\n43,899\n\n34,184\n\n대체인력  채용(B)\n\n796\n\n1,658\n\n1,957\n\n2,396\n\n2,836\n\n1,929\n\n비  율(B/A)\n\n3.8\n\n5.7\n\n5.5\n\n5.8\n\n6.5\n\n5.6\n\n자료: 고용노동부  자료를  바탕으로  국회예산정책처  작성\n\n위의 [표]의 자료에 따라 육아휴직자가 발생한 경우 대체 고용할 확률 \n\np의 값은 5.6%라고 가정한다. 그리고 비용이 발생한다고 가정하여 위\n\n의 수식을 다시 작성하면 다음의 수식과 같다.\n\nN×p×X + N×육아휴직급여액 - N×P > 0\n\n(1)\n\n- 9 -\n\n\x0c- 10 -\n\nN×5.6%×X + N×P×40% - N×P > 0\n\n0.056×X > 0.6P\n\nX > 10.7×P\n\n(2)\n\n(3)\n\n(5)\n\n위의 수식에 육아휴직자가 받는 월 급여액을 대입하여 대체고용인력\n\n자에게 지급하는 월 급여액을 추정하여 보자. 육아휴직자가 월 200만\n\n원을 받는다고 가정하면, 대체고용인력자에게 육아휴직자가 받는 월 \n\n급여액의 10.7배에 달하는 월 21,428,571원 이상을 지급해야 추가 비용\n\n이 발생한다. 대체고용인력자에게 육아휴직자보다 더 많은 월 ...

# %%
type(doc)
# Out:
# str

# %%
len(doc)
# Out:
# 46324

# %%
'안녕하세요, 재민입니다.'.split()
# Out:
# ['안녕하세요,', '재민입니다.']

# %% [markdown]
# # Tokenization

# %%
from konlpy.tag import Twitter
twitter = Twitter()

# %%
def pos_tag(doc):
    word_pos_list = []
    for word, pos in twitter.pos(doc):
        word_pos = word+'/'+pos
        word_pos_list.append(word_pos)
    return word_pos_list

# %%
pos_tag('우리 정부')
# Out:
# ['우리/Noun', '정부/Noun']

# %%
tokens = pos_tag(doc)

# %%
tokens
# Out:
# ['지방공무원법/Noun',
#  '일부/Noun',
#  '개정/Noun',
#  '법률/Noun',
#  '안/Noun',
#  '(/Punctuation',
#  '정의화/Noun',
#  '의원/Noun',
#  '대표/Noun',
#  '발의/Noun',
#  ')/Punctuation',
#  '의/Noun',
#  '안/Noun',
#  '번/Noun',
#  '호/Noun',
#  '9890/Number',
#  '발의/Noun',
#  '연월일/Noun',
#  ':/Punctuation',
#  '2010/Number',
#  './Punctuation',
#  '11/Number',
#  './Punctuation',
#  '12/Number',
#  './Punctuation',
#  '발/Noun',
#  '의/Noun',
#  '자/Noun',
#  ':/Punctuation',
#  '정의화/Noun',
#  '․/Foreign',
#  '이명수/Noun',
#  '․/Foreign',
#  '김을동/Noun',
#  '이사철/Noun',
#  '․/Foreign',
#  '여상규/Noun',
#  '․/Foreign',
#  '안규백/Noun',
#  '황영철/Noun',
#  '․/Foreign',
#  '박영아/Noun',
#  '․/Foreign',
#  '김정훈/Noun',
#  '김학송/Noun',
#  '의원/Noun',
#  '(/Punctuation',
#  '10/Number',
#  '인/Noun',
#  ')/Punctuation',
#  '제안/Noun',
#  '이유/Noun',
#  '및/Noun',
#  '주요/Noun',
#  '내용/Noun',
#  '초등학교/Noun',
#  '저학년/Noun',
#  '의/Josa',
#  '경우/Noun',
#  '에도/Josa',
#  '부모/Noun',
#  '의/Josa',
#  '따뜻한/Adjective',
#  '사랑/Noun',
#  '과/Josa',
#  '보살핌/Verb',
#  '이/Eomi',
#  '필요/Noun',
#  '한/Verb',
#  '나이/Noun',
#  '이나/Josa',
#  ',/Punctuation',
#  '현재/Noun',
#  '공무원/Noun',
#  '이/Josa',
#  '자녀/Noun',
#  '를/Josa',
#  '양육/Noun',
#  '하기/Verb',
#  '위하여/Verb',
#  '육아휴직/Noun',
#  '을/Josa',
#  '할/Verb',
#  '수/Noun',
#  '있는/Adjective',
#  '자녀/Noun',
#  '의/Josa',
#  '나이/Noun',
#  '는/Josa',
#  '만/Noun',
#  '6/Number',
#  '세/Noun',
#  '이하/Noun',
#  '로/Josa',
#  '되어/Verb',
#  '있어/Adjective',
#  '초등학교/Noun',
#  '저학년/Noun',
#  '인/Josa',
#  '자녀/Noun',
#  '를/Josa',
#  '돌보기/Verb',
#  '위해서/Verb',
#  '는/Eomi',
#  '해당/Noun',
#  '부모님/Noun',
#  '은/Josa',
#  '일자리/Noun',
#  '를/Josa',
#  '그만/Adverb',
#  '두어/Verb',
#  '야/Eomi',
#  '하고/Verb',
#  '이는/Verb',
#  '곧/Noun',
#  '출산/Noun',
#  '의욕/Noun',
#  '을/Josa',
#  '저하/Noun',
#  '시키는/Verb',
#  '문제/Noun',
#  '로/Josa',
#  '이어질/Verb',
#  '수/Noun',
#  '있/Adjective',
#  '을/Eomi',
#  '것임/Noun',
#  './Punctuation',
#  '따라서/Noun',
#  '육아휴직/Noun',
#  '이/Josa',
#  '가능한/Adjective',
#  '자녀/Noun',
#  '의/Josa',
#  '연령/Noun',
#  '을/Josa',
#  '만/Noun',
#  '8/Number',
#  '세/Noun',
#  '이하/Noun',
#  '로/Josa',
#  '개정/Noun',
#  '하려/Verb',
#  '는/Verb',
#  '것임/Noun',
#  '(/Punctuation',
#  '안/Noun',
#  '제/Noun',
#  '63/Number',
#  '조제/Noun',
#  '2/Number',
#  '항제/Noun',
#  '4/Number',
#  '호/Noun',
#  ')./Punctuation',
#  '-/Punctuation',
#  '1/Number',
#  '-/Punctuation',
#  '법률/Noun',
#  '제/Noun',
#  '호/Noun',
#  '지방공무원법/Noun',
#  '일부/Noun',
#  '개정/Noun',
#  '법률/Noun',
#  '안/Noun',
#  '지방공무원법/Noun',
#  '일부/Noun',
#  '를/Josa',
#  '다음/Noun',
#  '과/Josa',
#  '같이/Josa',
#  '개정/Noun',
#  '한/Verb',
#  '다/Eomi',
#  './Punctuation',
#  '제/Noun',
#  '63/Number',
#  '조제/Noun',
#  '2/Number',
#  '항제/Noun',
#  '4/Number',
#  '호/Noun',
#  '중/Noun',
#  '“/Foreign',
#  '만/Noun',
#  '6/Number',
#  '세/Noun',
#  '이하/Noun',
#  '의/Josa',
#  '초등학교/Noun',
#  '취학/Noun',
#  '전/Noun',
#  '자녀/Noun',
#  '를/Josa',
#  '”/Foreign',
#  '을/Josa',
#  '“/Foreign',
#  '만/Noun',
#  '8/Number',
#  '세/Noun',
#  '이하/Noun',
#  '(/Punctuation',
#  '취학/Noun',
#  '중인/Noun',
#  '경우/Noun',
#  '에는/Josa',
#  '초등학교/Noun',
#  '2/Number',
#  '학년/Noun',
#  '이하/Noun',
#  '를/Josa',
#  '말한/Verb',
#  '다/Eomi',
#  ')/Punctuation',
#  '의/Noun',
#  '자녀/Noun',
#  '를/Josa',
#  '”/Foreign',
#  '로/Noun',
#  '한/Verb',
#  '다/Eomi',
#  './Punctuation',
#  '부/Noun',
#  '칙/Noun',
#  '이/Noun',
#  '법/Noun',
#  '은/Josa',
#  '공포/Noun',
#  '한/Josa',
#  '날/Noun',
#  '부터/Josa',
#  '시행/Noun',
#  '한/Verb',
#  '다/Eomi',
#  './Punctuation',
#  '-/Punctuation',
#  '3/Number',
#  '-/Punctuation',
#  '신/Noun',
#  '·/Foreign',
#  '구조/Noun',
#  '문대비/Noun',
#  '표/Noun',
#  '현/Noun',
#  '행/Noun',
#  '개/Noun',
#  '정/Noun',
#  '안/Noun',
#  '제/Noun',
#  '63/Number',
#  '조/Noun',
#  '(/Punctuation',
#  '휴직/Noun',
#  ')/Punctuation',
#  '①/Foreign',
#  '(/Punctuation',
#  '생/Noun',
#  '략/Noun',
#  ')/Punctuation',
#  '제/Noun',
#  '63/Number',
#  '조/Noun',
#  '(/Punctuation',
#  '휴직/Noun',
#  ')/Punctuation',
#  '①/Foreign',
#  '(/Punctuation',
#  '현행/Noun',
#  '과/Josa',
#  '같/Adjective',
#  '음/Eomi',
#  ')/Punctuation',
#  '②/Foreign',
#  '공무원/Noun',
#  '이/Josa',
#  '다음/Noun',
#  '각/Noun',
#  '호의/Noun',
#  '어/Noun',
#  '②/Foreign',
#  '-------------------------/Punctuation',
#  '느/Noun',
#  '하나/Noun',
#  '에/Josa',
#  '해당하는/Verb',
#  '사유/Noun',
#  '로/Josa',
#  '휴/Exclamation',
#  '----------------------------/Punctuation',
#  '직/Noun',
#  '을/Josa',
#  '원하면/Verb',
#  '임용/Noun',
#  '권/Suffix',
#  '자는/Verb',
#  '휴직/Noun',
#  '----------------------------/Punctuation',
#  '을/Josa',
#  '명/Noun',
#  '할/Verb',
#  '수/Noun',
#  '있다/Adjective',
#  './Punctuation',
#  '다만/Noun',
#  ',/Punctuation',
#  '제/Noun',
#  '4/Number',
#  '호/Noun',
#  '-------------.---------------/Punctuation',
#  '의/Noun',
#  '경우/Noun',
#  '에는/Josa',
#  '대통령령/Noun',
#  '으로/Josa',
#  '정/Noun',
#  '----------------------------/Punctuation',
#  '하는/Verb',
#  '특별한/Adjective',
#  '사정/Noun',
#  '이/Josa',
#  '없으/Adjective',
#  '면/Eomi',
#  '휴/Exclamation',
#  '----------------------------/Punctuation',
#  '직/Noun',
#  '을/Josa',
#  '명/Noun',
#  '하여/Verb',
#  '야/Eomi',
#  '한/Verb',
#  '다/Eomi',
#  './Punctuation',
#  '--------------./Punctuation',
#  '1/Number',
#  './Punctuation',
#  '∼/Foreign',
#  '3/Number',
#  './Punctuation',
#  '(/Punctuation',
#  '생/Noun',
#  '략/Noun',
#  ')/Punctuation',
#  '1/Number',
#  './Punctuation',
#  '∼/Foreign',
#  '3/Number',
#  './Punctuation',
#  '(/Punctuation',
#  '현행/Noun',
#  '과/Josa',
#  '같/Adjective',
#  '음/Eomi',
#  ')/Punctuation',
#  '4/Number',
#  './Punctuation',
#  '만/Noun',
#  '6/Number',
#  '세/Noun',
#  '이하/Noun',
#  '의/Josa',
#  '초등학교/Noun',
#  '취/Noun',
#  '4/Number',
#  './Punctuation',
#  '만/Noun',
#  '8/Number',
#  '세/Noun',
#  '이하/Noun',
#  '(/Punctuation',
#  '취학/Noun',
#  '중인/Noun',
#  '경우/Noun',
#  '학/Noun',
#  '전/Noun',
#  '자녀/Noun',
#  '를/Josa',
#  '양육/Noun',
#  '하기/Verb',
#  '위하/Noun',
#  '에는/Josa',
#  '초등학교/Noun',
#  '2/Number',
#  '학년/Noun',
#  '이하/Noun',
#  '를/Josa',
#  '여/Noun',
#  '필요하거/Adjective',
#  '나/Eomi',
#  '여자/Noun',
#  '공무원/Noun',
#  '이/Josa',
#  '말한/Verb',
#  '다/Eomi',
#  ')/Punctuation',
#  '의/Noun',
#  '자녀/Noun',
#  '를/Josa',
#  '----------/Punctuation',
#  '임신/Noun',
#  '또는/Adverb',
#  '출산/Noun',
#  '하게/Verb',
#  '되었/Verb',
#  '을/Eomi',
#  '---------------------------/Punctuation',
#  '때/Noun',
#  '---------------------------/Punctuation',
#  '5/Number',
#  './Punctuation',
#  '⋅/Foreign',
#  '6/Number',
#  './Punctuation',
#  '(/Punctuation',
#  '생/Noun',
#  '략/Noun',
#  ')/Punctuation',
#  '③⋅④/Foreign',
#  '(/Punctuation',
#  '생/Noun',
#  '략/Noun',
#  ')/Punctuation',
#  '--------/Punctuation',
#  '5/Number',
#  './Punctuation',
#  '⋅/Foreign',
#  '6/Number',
#  './Punctuation',
#  '(/Punctuation',
#  '현행/Noun',
#  '과/Josa',
#  '같/Adjective',
#  '음/Eomi',
#  ')/Punctuation',
#  '③⋅④/Foreign',
#  '(/Punctuation',
#  '현행/Noun',
#  '과/Josa',
#  '같/Adjective',
#  '음/Eomi',
#  ')/Punctuation',
#  '-/Punctuation',
#  '5/Number',
#  '-/Punctuation',
#  '지방공무원법/Noun',
#  '일부/Noun',
#  '개정/Noun',
#  '법률/Noun',
#  '안/Noun',
#  '등/Noun',
#  '비용/Noun',
#  '추계/Noun',
#  '서/Josa',
#  '미/Adjective',
#  '첨부/Noun',
#  '사유/Noun',
#  '서/Josa',
#  '1/Number',
#  './Punctuation',
#  '재정/Noun',
#  '수반/Noun',
#  '요인/Noun',
#  '개정안/Noun',
#  '에서/Josa',
#  '｢/Foreign',
#  '국가공무원/Noun',
#  '법/Noun',
#  '｣/Foreign',
#  '제/Noun',
#  '71/Number',
#  '조제/Noun',
#  '2/Number',
#  '항제/Noun',
#  '4/Number',
#  '호/Noun',
#  '중/Noun',
#  '국가공무원/Noun',
#  '의/Josa',
#  '육아/Noun',
#  '휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '의/Josa',
#  '연령/Noun',
#  '을/Josa',
#  '만/Noun',
#  '6/Number',
#  '세/Noun',
#  '이하/Noun',
#  '에서/Josa',
#  '만/Noun',
#  '8/Number',
#  '세/Noun',
#  '이하/Noun',
#  '로/Josa',
#  '하고/Verb',
#  ',/Punctuation',
#  '｢/Foreign',
#  '지방/Noun',
#  '공/Noun',
#  '무/Noun',
#  '원/Suffix',
#  '법/Noun',
#  '｣/Foreign',
#  '제/Noun',
#  '63/Number',
#  '조제/Noun',
#  '2/Number',
#  '항제/Noun',
#  '4/Number',
#  '호/Noun',
#  '중/Noun',
#  '지방/Noun',
#  '공무원/Noun',
#  '의/Josa',
#  '육아휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '의/Josa',
#  '연/Noun',
#  '령/Noun',
#  '을/Josa',
#  '만/Noun',
#  '6/Number',
#  '세/Noun',
#  '이하/Noun',
#  '에서/Josa',
#  '만/Noun',
#  '8/Number',
#  '세/Noun',
#  '이하/Noun',
#  '로/Josa',
#  '하고/Verb',
#  ',/Punctuation',
#  '｢/Foreign',
#  '교육/Noun',
#  '공무원/Noun',
#  '법/Noun',
#  '｣/Foreign',
#  '제/Noun',
#  '44/Number',
#  '조제/Noun',
#  '1/Number',
#  '항/Noun',
#  '제/Noun',
#  '7/Number',
#  '조/Noun',
#  '중/Noun',
#  '교육/Noun',
#  '공무원/Noun',
#  '의/Josa',
#  '육아휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '의/Josa',
#  '연령/Noun',
#  '을/Josa',
#  '만/Noun',
#  '6/Number',
#  '세/Noun',
#  '이하/Noun',
#  '에서/Josa',
#  '만/Noun',
#  '8/Number',
#  '세/Noun',
#  '이하/Noun',
#  '로/Josa',
#  '하고/Verb',
#  ',/Punctuation',
#  '｢/Foreign',
#  '남녀/Noun',
#  '고용/Noun',
#  '평등/Noun',
#  '과/Josa',
#  '일/Noun',
#  '․/Foreign',
#  '가정/Noun',
#  '양립/Noun',
#  '지원/Noun',
#  '에/Josa',
#  '관한/Verb',
#  '법률/Noun',
#  '｣/Foreign',
#  '제/Noun',
#  '19/Number',
#  '조제/Noun',
#  '1/Number',
#  '항/Noun',
#  '중/Noun',
#  '근로자/Noun',
#  '육아휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '을/Josa',
#  '만/Noun',
#  '6/Number',
#  '세/Noun',
#  '이하/Noun',
#  '에서/Josa',
#  '만/Noun',
#  '8/Number',
#  '세/Noun',
#  '이하/Noun',
#  '로/Josa',
#  '조정함/Verb',
#  '에/Eomi',
#  '따라/Verb',
#  '추가/Noun',
#  '재정/Noun',
#  '소요/Noun',
#  '가/Josa',
#  '예상됨/Verb',
#  './Punctuation',
#  '2/Number',
#  './Punctuation',
#  '미/Adjective',
#  '첨부/Noun',
#  '근거/Noun',
#  '규정/Noun',
#  '｢/Foreign',
#  '의안/Noun',
#  '의/Josa',
#  '비용/Noun',
#  '추계/Noun',
#  '에/Josa',
#  '관한/Verb',
#  '규칙/Noun',
#  '｣/Foreign',
#  '제/Noun',
#  '3/Number',
#  '조제/Noun',
#  '1/Number',
#  '항/Noun',
#  '단서/Noun',
#  '중/Noun',
#  '제/Noun',
#  '1/Number',
#  '호/Noun',
#  '(/Punctuation',
#  '예상되는/Verb',
#  '비용/Noun',
#  '이/Josa',
#  '연/Noun',
#  '평균/Noun',
#  '10/Number',
#  '억원/Noun',
#  '미만/Noun',
#  '이/Determiner',
#  '거나/Noun',
#  '한시/Noun',
#  '적/Suffix',
#  '인/Josa',
#  '경비/Noun',
#  '로서/Noun',
#  '총/Noun',
#  '30/Number',
#  '억원/Noun',
#  '미만/Noun',
#  '인/Josa',
#  '경우/Noun',
#  ')/Punctuation',
#  '에/Josa',
#  '해당함/Verb',
#  './Punctuation',
#  '3/Number',
#  './Punctuation',
#  '미/Adjective',
#  '첨부/Noun',
#  '사유/Noun',
#  '개정안/Noun',
#  '에서/Josa',
#  '국가/Noun',
#  '․/Foreign',
#  '지방/Noun',
#  '․/Foreign',
#  '교육/Noun',
#  '공무원/Noun',
#  '및/Noun',
#  '근로자/Noun',
#  '가/Josa',
#  '육아휴직/Noun',
#  '을/Josa',
#  '신청할/Verb',
#  '수/Noun',
#  '있는/Adjective',
#  '자녀/Noun',
#  '의/Josa',
#  '연령/Noun',
#  '을/Josa',
#  '만/Noun',
#  '6/Number',
#  '세/Noun',
#  '이하/Noun',
#  '에서/Josa',
#  '만/Noun',
#  '8/Number',
#  '세/Noun',
#  '이하/Noun',
#  '로/Josa',
#  '상향/Noun',
#  '조정함/Verb',
#  '에/Eomi',
#  '따라/Verb',
#  '추가/Noun',
#  '재정/Noun',
#  '소요/Noun',
#  '가/Josa',
#  '예상된/Verb',
#  '다/Eomi',
#  './Punctuation',
#  '동/Noun',
#  '법률/Noun',
#  '개정안/Noun',
#  '이/Josa',
#  '2011/Number',
#  '년/Noun',
#  '에/Josa',
#  '시행/Noun',
#  '된/Verb',
#  '다/Eomi',
#  '고/Noun',
#  '가정/Noun',
#  '한/Josa',
#  '경우/Noun',
#  ',/Punctuation',
#  '2010/Number',
#  '년/Noun',
#  '현재/Noun',
#  '자녀/Noun',
#  '의/Josa',
#  '연령/Noun',
#  '이/Josa',
#  '7/Number',
#  '세이/Noun',
#  '고/Josa',
#  '육아휴직/Noun',
#  '을/Josa',
#  '신청/Noun',
#  '-/Punctuation',
#  '7/Number',
#  '-/Punctuation',
#  '-/Punctuation',
#  '8/Number',
#  '-/Punctuation',
#  '하지/Verb',
#  '않은/Verb',
#  '국가/Noun',
#  '․/Foreign',
#  '지방/Noun',
#  '․/Foreign',
#  '교육/Noun',
#  '공무원/Noun',
#  '및/Noun',
#  '근로자/Noun',
#  '가/Josa',
#  '대상/Noun',
#  '이/Josa',
#  '된/Verb',
#  '다/Eomi',
#  './Punctuation',
#  '대상/Noun',
#  '연령/Noun',
#  '의/Josa',
#  '확대됨/Verb',
#  '에/Eomi',
#  '따라/Verb',
#  '육아휴직/Noun',
#  '신청/Noun',
#  '자/Suffix',
#  '의/Josa',
#  '수가/Noun',
#  '어느/Adverb',
#  '정도/Noun',
#  '늘어날/Verb',
#  '것/Noun',
#  '으로/Josa',
#  '예상된/Verb',
#  '다/Eomi',
#  './Punctuation',
#  '이/Noun',
#  '경우/Noun',
#  '발생하는/Verb',
#  '비용/Noun',
#  '은/Josa',
#  '현행법/Noun',
#  '에/Josa',
#  '따르/Verb',
#  '면/Eomi',
#  '월/Noun',
#  '50/Number',
#  '만원/Noun',
#  '이나/Noun',
#  '현재/Noun',
#  '관련/Noun',
#  '법령/Noun',
#  '개정/Noun',
#  '이/Josa',
#  '추진/Noun',
#  '되/Verb',
#  '고/Eomi',
#  '있으/Adjective',
#  '며/Eomi',
#  ',/Punctuation',
#  '이/Noun',
#  '에/Josa',
#  '따라/Verb',
#  '2011/Number',
#  '년/Noun',
#  '에는/Josa',
#  '육아휴직/Noun',
#  '자/Suffix',
#  '가/Josa',
#  '지급/Noun',
#  '받는/Verb',
#  '월급/Noun',
#  '여/Josa',
#  '액/Noun',
#  '에/Josa',
#  '비례/Noun',
#  '하여/Verb',
#  '육아휴직/Noun',
#  '급/Suffix',
#  '여가/Noun',
#  '지급/Noun',
#  '되/Verb',
#  '기/Noun',
#  '때문/Noun',
#  '에/Josa',
#  '법령/Noun',
#  '개정/Noun',
#  '을/Josa',
#  '가정/Noun',
#  '하고/Josa',
#  '추계/Noun',
#  '한/Josa',
#  '다/Adverb',
#  './Punctuation',
#  '이러한/Adjective',
#  '경우/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '액/Noun',
#  '은/Josa',
#  '육아휴직/Noun',
#  '자/Suffix',
#  '가/Josa',
#  '지급/Noun',
#  '받는/Verb',
#  '월급/Noun',
#  '여의/Noun',
#  '40/Number',
#  '%/Punctuation',
#  '에/Josa',
#  '해당한/Verb',
#  '다/Eomi',
#  './Punctuation',
#  '육아휴직/Noun',
#  '자/Suffix',
#  '가/Josa',
#  '발생한/Verb',
#  '경우/Noun',
#  '발생하는/Verb',
#  '비용/Noun',
#  '은/Josa',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '인건비/Noun',
#  '와/Josa',
#  '육아휴직/Noun',
#  '자/Suffix',
#  '가/Josa',
#  '받는/Verb',
#  '월급/Noun',
#  '여/Josa',
#  '액/Noun',
#  '의/Josa',
#  '40/Number',
#  '%/Punctuation',
#  '이다/Josa',
#  './Punctuation',
#  '이/Noun',
#  '와/Josa',
#  '대비하여/Verb',
#  '육아휴직/Noun',
#  '자/Suffix',
#  '에게/Josa',
#  '지급하던/Verb',
#  '임금/Noun',
#  '은/Josa',
#  '더/Noun',
#  '이상/Noun',
#  '발생하지/Verb',
#  '않는/Verb',
#  '다/Eomi',
#  './Punctuation',
#  '따라서/Noun',
#  '실제/Noun',
#  '발생하는/Verb',
#  '순/Noun',
#  '비용/Noun',
#  '은/Josa',
#  '육/Noun',
#  '아/Exclamation',
#  '휴직/Noun',
#  '자/Suffix',
#  '에게/Josa',
#  '지급하던/Verb',
#  '월/Noun',
#  '급여/Noun',
#  '액/Noun',
#  '과/Josa',
#  '연령/Noun',
#  '확대/Noun',
#  '에/Josa',
#  '따라/Verb',
#  '발생하는/Verb',
#  '비용/Noun',
#  '인/Noun',
#  '육아휴직/Noun',
#  '자/Suffix',
#  '가/Josa',
#  '받던/Verb',
#  '월급/Noun',
#  '여/Josa',
#  '액/Noun',
#  '의/Josa',
#  '40/Number',
#  '%/Punctuation',
#  '와/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '인건비/Noun',
#  '의/Josa',
#  '차/Noun',
#  '액/Noun',
#  '인데/Josa',
#  '이/Noun',
#  '값/Noun',
#  '이/Josa',
#  '0/Number',
#  '보다/Verb',
#  '크/Verb',
#  '면/Eomi',
#  '추가/Noun',
#  '재정/Noun',
#  '소요/Noun',
#  '는/Josa',
#  '발생하지/Verb',
#  '않는/Verb',
#  '다고/Eomi',
#  '볼/Noun',
#  '수/Noun',
#  '있다/Adjective',
#  './Punctuation',
#  '추가/Noun',
#  '비용/Noun',
#  '발생/Noun',
#  '여부/Noun',
#  '를/Josa',
#  '정확하게/Adjective',
#  '알아보기/Verb',
#  '위하여/Verb',
#  '비용/Noun',
#  '에/Josa',
#  '대한/Noun',
#  '수리/Noun',
#  '모/Noun',
#  '델/Noun',
#  '을/Josa',
#  '만들/Verb',
#  '고/Eomi',
#  '이/Noun',
#  '에/Josa',
#  '따라/Verb',
#  '비용/Noun',
#  '발생/Noun',
#  '여부/Noun',
#  '를/Josa',
#  '알아보기/Verb',
#  '로/Eomi',
#  '하자/Noun',
#  './Punctuation',
#  '모델/Noun',
#  '에/Josa',
#  '사/Noun',
#  '용/Noun',
#  '되는/Verb',
#  '변수/Noun',
#  '를/Josa',
#  '다음/Noun',
#  '과/Josa',
#  '같이/Josa',
#  '정의/Noun',
#  '한/Verb',
#  '다/Eomi',
#  './Punctuation',
#  '발생/Noun',
#  ...]

# %%
len(tokens)
# Out:
# 18270

# %%
len(set(tokens))
# Out:
# 1720

# %% [markdown]
# # Word Vectorization

# %%
from gensim.models import word2vec

# %% [markdown]
# ## Train Vectorizer

# %%
wv_model = word2vec.Word2Vec([tokens], size=200)

# %%
wv_model.vector_size
# Out:
# 200

# %%
wv_model.wv.vocab
# Out:
# {'"/Punctuation': <gensim.models.keyedvectors.Vocab at 0x10f0f6400>,
#  '%/Punctuation': <gensim.models.keyedvectors.Vocab at 0x1313b0b38>,
#  '(/Punctuation': <gensim.models.keyedvectors.Vocab at 0x130c768d0>,
#  ')./Punctuation': <gensim.models.keyedvectors.Vocab at 0x130d0e438>,
#  ')/Punctuation': <gensim.models.keyedvectors.Vocab at 0x130c76908>,
#  '+/Punctuation': <gensim.models.keyedvectors.Vocab at 0x130d080f0>,
#  ',/Punctuation': <gensim.models.keyedvectors.Vocab at 0x130c9f978>,
#  '----------------------------/Punctuation': <gensim.models.keyedvectors.Vocab at 0x1313ac128>,
#  '---------------------------/Punctuation': <gensim.models.keyedvectors.Vocab at 0x1313ac588>,
#  '------------------------/Punctuation': <gensim.models.keyedvectors.Vocab at 0x130ceb630>,
#  '---/Punctuation': <gensim.models.keyedvectors.Vocab at 0x130ceb0b8>,
#  '-/Punctuation': <gensim.models.keyedvectors.Vocab at 0x130d0e358>,
#  './Punctuation': <gensim.models.keyedvectors.Vocab at 0x130c76fd0>,
#  '//Punctuation': <gensim.models.keyedvectors.Vocab at 0x130d02da0>,
#  '0/Number': <gensim.models.keyedvectors.Vocab at 0x130d08550>,
#  '02/Number': <gensim.models.keyedvectors.Vocab at 0x130d08a20>,
#  '08/Number': <gensim.models.keyedvectors.Vocab at 0x130d0eeb8>,
#  '09/Number': <gensim.models.keyedvectors.Vocab at 0x130d653c8>,
#  '1/Number': <gensim.models.keyedvectors.Vocab at 0x130d0e240>,
#  '10/Number': <gensim.models.keyedvectors.Vocab at 0x130c76da0>,
#  '11/Number': <gensim.models.keyedvectors.Vocab at 0x130c76dd8>,
#  '12/Number': <gensim.models.keyedvectors.Vocab at 0x130c76f28>,
#  '13/Number': <gensim.models.keyedvectors.Vocab at 0x130d029e8>,
#  '14/Number': <gensim.models.keyedvectors.Vocab at 0x130d67588>,
#  '15/Number': <gensim.models.keyedvectors.Vocab at 0x130d02a90>,
#  '16/Number': <gensim.models.keyedvectors.Vocab at 0x130d16b70>,
#  '17/Number': <gensim.models.keyedvectors.Vocab at 0x130d674e0>,
#  '18/Number': <gensim.models.keyedvectors.Vocab at 0x130d671d0>,
#  '19/Number': <gensim.models.keyedvectors.Vocab at 0x1313b08d0>,
#  '2/Number': <gensim.models.keyedvectors.Vocab at 0x130d0e5c0>,
#  '20/Number': <gensim.models.keyedvectors.Vocab at 0x130d02400>,
#  '200/Number': <gensim.models.keyedvectors.Vocab at 0x130d026d8>,
#  '2007/Number': <gensim.models.keyedvectors.Vocab at 0x130d02208>,
#  '2010/Number': <gensim.models.keyedvectors.Vocab at 0x130c76eb8>,
#  '2011/Number': <gensim.models.keyedvectors.Vocab at 0x1313b0400>,
#  '2012/Number': <gensim.models.keyedvectors.Vocab at 0x130d65a58>,
#  '21/Number': <gensim.models.keyedvectors.Vocab at 0x130d02358>,
#  '22/Number': <gensim.models.keyedvectors.Vocab at 0x130d163c8>,
#  '24/Number': <gensim.models.keyedvectors.Vocab at 0x130ceb4e0>,
#  '26/Number': <gensim.models.keyedvectors.Vocab at 0x130ceb208>,
#  '29/Number': <gensim.models.keyedvectors.Vocab at 0x130d022e8>,
#  '3/Number': <gensim.models.keyedvectors.Vocab at 0x130c91e80>,
#  '30/Number': <gensim.models.keyedvectors.Vocab at 0x1313b0978>,
#  '31/Number': <gensim.models.keyedvectors.Vocab at 0x130d659e8>,
#  '34/Number': <gensim.models.keyedvectors.Vocab at 0x130d024e0>,
#  '35/Number': <gensim.models.keyedvectors.Vocab at 0x130d02438>,
#  '36/Number': <gensim.models.keyedvectors.Vocab at 0x130d16f28>,
#  '4/Number': <gensim.models.keyedvectors.Vocab at 0x130d0e7f0>,
#  '40/Number': <gensim.models.keyedvectors.Vocab at 0x1313b0c50>,
#  '41/Number': <gensim.models.keyedvectors.Vocab at 0x130d02ac8>,
#  '43/Number': <gensim.models.keyedvectors.Vocab at 0x130d02d30>,
#  '44/Number': <gensim.models.keyedvectors.Vocab at 0x126a63198>,
#  '46/Number': <gensim.models.keyedvectors.Vocab at 0x130d16240>,
#  '491/Number': <gensim.models.keyedvectors.Vocab at 0x130d0e588>,
#  '5/Number': <gensim.models.keyedvectors.Vocab at 0x1313ac5f8>,
#  '50/Number': <gensim.models.keyedvectors.Vocab at 0x1313b00b8>,
#  '6/Number': <gensim.models.keyedvectors.Vocab at 0x130d0e9e8>,
#  '63/Number': <gensim.models.keyedvectors.Vocab at 0x130d0e6a0>,
#  '6350/Number': <gensim.models.keyedvectors.Vocab at 0x130d0e1d0>,
#  '7/Number': <gensim.models.keyedvectors.Vocab at 0x1313aee80>,
#  '71/Number': <gensim.models.keyedvectors.Vocab at 0x1313ac978>,
#  '710/Number': <gensim.models.keyedvectors.Vocab at 0x130d65ef0>,
#  '712/Number': <gensim.models.keyedvectors.Vocab at 0x130d0edd8>,
#  '748/Number': <gensim.models.keyedvectors.Vocab at 0x130d0e3c8>,
#  '781/Number': <gensim.models.keyedvectors.Vocab at 0x130d0e6d8>,
#  '796/Number': <gensim.models.keyedvectors.Vocab at 0x130d024a8>,
#  '8/Number': <gensim.models.keyedvectors.Vocab at 0x130d0e898>,
#  '836/Number': <gensim.models.keyedvectors.Vocab at 0x130d022b0>,
#  '9/Number': <gensim.models.keyedvectors.Vocab at 0x130d025c0>,
#  ':/Punctuation': <gensim.models.keyedvectors.Vocab at 0x130c76390>,
#  '</Punctuation': <gensim.models.keyedvectors.Vocab at 0x130d167f0>,
#  '>/Punctuation': <gensim.models.keyedvectors.Vocab at 0x130d02710>,
#  'A/Alpha': <gensim.models.keyedvectors.Vocab at 0x130d02828>,
#  'B/Alpha': <gensim.models.keyedvectors.Vocab at 0x130d02c18>,
#  'N/Alpha': <gensim.models.keyedvectors.Vocab at 0x130d08908>,
#  'P/Alpha': <gensim.models.keyedvectors.Vocab at 0x130d08978>,
#  'UAE/Alpha': <gensim.models.keyedvectors.Vocab at 0x130d65d30>,
#  'X/Alpha': <gensim.models.keyedvectors.Vocab at 0x130d08128>,
#  '[/Punctuation': <gensim.models.keyedvectors.Vocab at 0x130d02e48>,
#  ']/Punctuation': <gensim.models.keyedvectors.Vocab at 0x130d02048>,
#  'p/Alpha': <gensim.models.keyedvectors.Vocab at 0x130d089b0>,
#  '´/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d0eb00>,
#  '·/Foreign': <gensim.models.keyedvectors.Vocab at 0x130c91cf8>,
#  '×/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d088d0>,
#  '‘/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d65358>,
#  '’/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d65438>,
#  '“/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d0e080>,
#  '”/Foreign': <gensim.models.keyedvectors.Vocab at 0x130b42240>,
#  '․/Foreign': <gensim.models.keyedvectors.Vocab at 0x130c76f60>,
#  '∼/Foreign': <gensim.models.keyedvectors.Vocab at 0x1313ac438>,
#  '⋅/Foreign': <gensim.models.keyedvectors.Vocab at 0x1313ac630>,
#  '①/Foreign': <gensim.models.keyedvectors.Vocab at 0x130c917b8>,
#  '②/Foreign': <gensim.models.keyedvectors.Vocab at 0x130c79f98>,
#  '③/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d16470>,
#  '④/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d65080>,
#  '⑤/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d083c8>,
#  '□/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d0e550>,
#  '○/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d654a8>,
#  '◦/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d65048>,
#  '「/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d67390>,
#  '」/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d672e8>,
#  'ㆍ/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d16b00>,
#  '休職/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d08588>,
#  '第/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d08710>,
#  '號/Foreign': <gensim.models.keyedvectors.Vocab at 0x130d086d8>,
#  '가/Josa': <gensim.models.keyedvectors.Vocab at 0x1313b0630>,
#  '가/Verb': <gensim.models.keyedvectors.Vocab at 0x130d020b8>,
#  '가능/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac9e8>,
#  '가정/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b05f8>,
#  '각/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65f60>,
#  '각각/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16eb8>,
#  '간/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65a90>,
#  '간호/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02198>,
#  '값/Noun': <gensim.models.keyedvectors.Vocab at 0x130d087b8>,
#  '같/Adjective': <gensim.models.keyedvectors.Vocab at 0x130c79f28>,
#  '같다/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d029b0>,
#  '같은/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d16e48>,
#  '같이/Josa': <gensim.models.keyedvectors.Vocab at 0x130d0e128>,
#  '개/Noun': <gensim.models.keyedvectors.Vocab at 0x130c917f0>,
#  '개월/Noun': <gensim.models.keyedvectors.Vocab at 0x130d166a0>,
#  '개정/Noun': <gensim.models.keyedvectors.Vocab at 0x130c769e8>,
#  '개정안/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac860>,
#  '거나/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0a20>,
#  '거래/Noun': <gensim.models.keyedvectors.Vocab at 0x130d169b0>,
#  '거짓/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0ec88>,
#  '것/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0358>,
#  '것임/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e780>,
#  '결과/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16ba8>,
#  '결의/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0eac8>,
#  '결정/Noun': <gensim.models.keyedvectors.Vocab at 0x130d167b8>,
#  '결혼/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0eef0>,
#  '경/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08ba8>,
#  '경과/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16710>,
#  '경력/Noun': <gensim.models.keyedvectors.Vocab at 0x130cf0dd8>,
#  '경비/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b09b0>,
#  '경우/Noun': <gensim.models.keyedvectors.Vocab at 0x130c9fc50>,
#  '계/Noun': <gensim.models.keyedvectors.Vocab at 0x130d670b8>,
#  '계약서/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb438>,
#  '계획/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16160>,
#  '고/Eomi': <gensim.models.keyedvectors.Vocab at 0x1313b0390>,
#  '고/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0470>,
#  '고용/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0b70>,
#  '고용노동부/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02dd8>,
#  '고의/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16d68>,
#  '공/Noun': <gensim.models.keyedvectors.Vocab at 0x1313aca58>,
#  '공개/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65550>,
#  '공무원/Noun': <gensim.models.keyedvectors.Vocab at 0x130c9fc18>,
#  '공시/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb3c8>,
#  '공정/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16a20>,
#  '공포/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b2e10>,
#  '과/Josa': <gensim.models.keyedvectors.Vocab at 0x130c9fa58>,
#  '과/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02908>,
#  '과의/Josa': <gensim.models.keyedvectors.Vocab at 0x130b6cc88>,
#  '과장/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e400>,
#  '과정/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16400>,
#  '관/Noun': <gensim.models.keyedvectors.Vocab at 0x130d67550>,
#  '관계/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16048>,
#  '관련/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0208>,
#  '관리/Noun': <gensim.models.keyedvectors.Vocab at 0x130d672b0>,
#  '관하여/Verb': <gensim.models.keyedvectors.Vocab at 0x130d164e0>,
#  '관한/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b0278>,
#  '관할/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb2b0>,
#  '광고/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb4a8>,
#  '교육/Noun': <gensim.models.keyedvectors.Vocab at 0x126a630b8>,
#  '구/Noun': <gensim.models.keyedvectors.Vocab at 0x130d650b8>,
#  '구조/Noun': <gensim.models.keyedvectors.Vocab at 0x130c91ba8>,
#  '구청/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb240>,
#  '국/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65b70>,
#  '국가/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0080>,
#  '국가공무원/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac908>,
#  '국군/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65be0>,
#  '국민/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02160>,
#  '국방부/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e4e0>,
#  '국제/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65470>,
#  '국회/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16080>,
#  '국회예산정책처/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02c88>,
#  '군/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65da0>,
#  '군/Suffix': <gensim.models.keyedvectors.Vocab at 0x130d65898>,
#  '군사/Noun': <gensim.models.keyedvectors.Vocab at 0x130d652e8>,
#  '군수/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb278>,
#  '권/Suffix': <gensim.models.keyedvectors.Vocab at 0x1313ac198>,
#  '규모/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65ac8>,
#  '규정/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0a90>,
#  '그/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08668>,
#  '그리고/Conjunction': <gensim.models.keyedvectors.Vocab at 0x130d02f60>,
#  '근거/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b06d8>,
#  '근로자/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0e80>,
#  '급/Suffix': <gensim.models.keyedvectors.Vocab at 0x1313b0550>,
#  '급여/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0f98>,
#  '기/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0438>,
#  '기간/Noun': <gensim.models.keyedvectors.Vocab at 0x130cfea90>,
#  '기관/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16320>,
#  '기록/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb470>,
#  '기준/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02ef0>,
#  '기타/Noun': <gensim.models.keyedvectors.Vocab at 0x130d658d0>,
#  '기획재정부/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65588>,
#  '김정훈/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76d30>,
#  '까지/Josa': <gensim.models.keyedvectors.Vocab at 0x130d08b38>,
#  '나/Eomi': <gensim.models.keyedvectors.Vocab at 0x1313ac4a8>,
#  '나/Josa': <gensim.models.keyedvectors.Vocab at 0x130d65630>,
#  '나/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16438>,
#  '나이/Noun': <gensim.models.keyedvectors.Vocab at 0x130c9f908>,
#  '날/Noun': <gensim.models.keyedvectors.Vocab at 0x130c91780>,
#  '남녀/Noun': <gensim.models.keyedvectors.Vocab at 0x1313aee48>,
#  '내용/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76ba8>,
#  '년/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0128>,
#  '년도/Noun': <gensim.models.keyedvectors.Vocab at 0x130d656d8>,
#  '는/Eomi': <gensim.models.keyedvectors.Vocab at 0x130d0eda0>,
#  '는/Josa': <gensim.models.keyedvectors.Vocab at 0x130d0ee10>,
#  '는/Verb': <gensim.models.keyedvectors.Vocab at 0x130d0e908>,
#  '다/Adverb': <gensim.models.keyedvectors.Vocab at 0x1313b02e8>,
#  '다/Eomi': <gensim.models.keyedvectors.Vocab at 0x130d0e0f0>,
#  '다고/Eomi': <gensim.models.keyedvectors.Vocab at 0x130d08438>,
#  '다만/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac278>,
#  '다시/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02668>,
#  '다음/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e278>,
#  '단계/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16668>,
#  '단서/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b05c0>,
#  '단위/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02128>,
#  '단체/Noun': <gensim.models.keyedvectors.Vocab at 0x130d160f0>,
#  '당사자/Noun': <gensim.models.keyedvectors.Vocab at 0x130d164a8>,
#  '대/Suffix': <gensim.models.keyedvectors.Vocab at 0x130d02630>,
#  '대/Verb': <gensim.models.keyedvectors.Vocab at 0x130d168d0>,
#  '대상/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0940>,
#  '대상자/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08828>,
#  '대체/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08080>,
#  '대통령령/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac2b0>,
#  '대표/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76940>,
#  '대하여/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08400>,
#  '대한/Noun': <gensim.models.keyedvectors.Vocab at 0x130d081d0>,
#  '더/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08d30>,
#  '도/Josa': <gensim.models.keyedvectors.Vocab at 0x130d02320>,
#  '도/Noun': <gensim.models.keyedvectors.Vocab at 0x11016c940>,
#  '동의/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65eb8>,
#  '되/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b06a0>,
#  '되는/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08a90>,
#  '된/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b0f28>,
#  '될/Verb': <gensim.models.keyedvectors.Vocab at 0x130d65240>,
#  '등/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac668>,
#  '등록/Noun': <gensim.models.keyedvectors.Vocab at 0x130cf0978>,
#  '따라/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b03c8>,
#  '따라서/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e828>,
#  '따르/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b0748>,
#  '따른/Verb': <gensim.models.keyedvectors.Vocab at 0x130d02e80>,
#  '때/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac5c0>,
#  '때문/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0dd8>,
#  '또는/Adverb': <gensim.models.keyedvectors.Vocab at 0x1313ac518>,
#  '라/Josa': <gensim.models.keyedvectors.Vocab at 0x130d16278>,
#  '라도/Eomi': <gensim.models.keyedvectors.Vocab at 0x130d02550>,
#  '략/Noun': <gensim.models.keyedvectors.Vocab at 0x130c790f0>,
#  '령/Noun': <gensim.models.keyedvectors.Vocab at 0x1313accf8>,
#  '로/Josa': <gensim.models.keyedvectors.Vocab at 0x130d0ecf8>,
#  '로/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b2f98>,
#  '록/Eomi': <gensim.models.keyedvectors.Vocab at 0x130d08e48>,
#  '를/Josa': <gensim.models.keyedvectors.Vocab at 0x130c9f748>,
#  '를/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02d68>,
#  '마/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16208>,
#  '만/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e7b8>,
#  '만원/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0fd0>,
#  '많은/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d02be0>,
#  '말한/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b2f60>,
#  '며/Eomi': <gensim.models.keyedvectors.Vocab at 0x1313b0b00>,
#  '면/Eomi': <gensim.models.keyedvectors.Vocab at 0x1313ac3c8>,
#  '명/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac208>,
#  '목적/Noun': <gensim.models.keyedvectors.Vocab at 0x130d67438>,
#  '무/Noun': <gensim.models.keyedvectors.Vocab at 0x1313aca90>,
#  '문/Noun': <gensim.models.keyedvectors.Vocab at 0x10f1d60f0>,
#  '문대비/Noun': <gensim.models.keyedvectors.Vocab at 0x130c91f98>,
#  '미/Adjective': <gensim.models.keyedvectors.Vocab at 0x1313ac748>,
#  '미만/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0ba8>,
#  '및/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76c88>,
#  '바/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65128>,
#  '바탕/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02b00>,
#  '밖/Noun': <gensim.models.keyedvectors.Vocab at 0x130d67080>,
#  '받는/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b0710>,
#  '발/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76e80>,
#  '발생/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08748>,
#  '발생하는/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b0198>,
#  '발생하지/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08c88>,
#  '발생한/Verb': <gensim.models.keyedvectors.Vocab at 0x130d082b0>,
#  '발의/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76c50>,
#  '백만원/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e668>,
#  '번/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76898>,
#  '번역본/Noun': <gensim.models.keyedvectors.Vocab at 0x130cebf60>,
#  '벌금/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16e80>,
#  '벌칙/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16b38>,
#  '범죄/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08dd8>,
#  '법/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b2e80>,
#  '법령/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b02b0>,
#  '법률/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76860>,
#  '법제처장/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16390>,
#  '변경/Noun': <gensim.models.keyedvectors.Vocab at 0x130d162e8>,
#  '보다/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08470>,
#  '보여/Verb': <gensim.models.keyedvectors.Vocab at 0x130d02ba8>,
#  '보유/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65828>,
#  '보인/Verb': <gensim.models.keyedvectors.Vocab at 0x130d02b70>,
#  '보존/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb1d0>,
#  '보호/Noun': <gensim.models.keyedvectors.Vocab at 0x130d67198>,
#  '부/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b2fd0>,
#  '부담/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16e10>,
#  '부대/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65c50>,
#  '부분/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65320>,
#  '부터/Josa': <gensim.models.keyedvectors.Vocab at 0x130c91da0>,
#  '분/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65940>,
#  '불구하고/Verb': <gensim.models.keyedvectors.Vocab at 0x130d084a8>,
#  '비/Noun': <gensim.models.keyedvectors.Vocab at 0x130d025f8>,
#  '비용/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac6a0>,
#  '사/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08940>,
#  '사무소/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb2e8>,
#  '사실/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16c18>,
#  '사유/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac0f0>,
#  '사정/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac390>,
#  '사항/Noun': <gensim.models.keyedvectors.Vocab at 0x130d165c0>,
#  '상/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65860>,
#  '상/Suffix': <gensim.models.keyedvectors.Vocab at 0x130d08358>,
#  '상대방/Noun': <gensim.models.keyedvectors.Vocab at 0x130cf0908>,
#  '상향/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0898>,
#  '생/Noun': <gensim.models.keyedvectors.Vocab at 0x130c91518>,
#  '생활/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02e10>,
#  '서/Josa': <gensim.models.keyedvectors.Vocab at 0x1313ac710>,
#  '서류/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb128>,
#  '선박/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e048>,
#  '설/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16860>,
#  '성폭력/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08da0>,
#  '세/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0ed30>,
#  '소말리아/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e2b0>,
#  '소요/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0ef0>,
#  '손해/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16da0>,
#  '수/Noun': <gensim.models.keyedvectors.Vocab at 0x130c9cd30>,
#  '수급/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02898>,
#  '수립/Noun': <gensim.models.keyedvectors.Vocab at 0x130d654e0>,
#  '수반/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac7f0>,
#  '수식/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08048>,
#  '수업/Noun': <gensim.models.keyedvectors.Vocab at 0x130d028d0>,
#  '시/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65b00>,
#  '시장/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb550>,
#  '시행/Noun': <gensim.models.keyedvectors.Vocab at 0x130c91b70>,
#  '신/Noun': <gensim.models.keyedvectors.Vocab at 0x130c91dd8>,
#  '신고/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb400>,
#  '신상/Noun': <gensim.models.keyedvectors.Vocab at 0x130cf0400>,
#  '신설/Noun': <gensim.models.keyedvectors.Vocab at 0x130b6cb00>,
#  '신청/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0160>,
#  '신청할/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b0668>,
#  '실/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16a58>,
#  '실제/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08fd0>,
#  '심의/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65668>,
#  '아/Exclamation': <gensim.models.keyedvectors.Vocab at 0x130d08ac8>,
#  '아니/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d02a58>,
#  '아랍에미리트/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65cc0>,
#  '안/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76b38>,
#  '안보리/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0ee80>,
#  '안전/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65400>,
#  '않/Verb': <gensim.models.keyedvectors.Vocab at 0x130d02cc0>,
#  '않는/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08b00>,
#  '않은/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b0d68>,
#  '알아보기/Verb': <gensim.models.keyedvectors.Vocab at 0x130d082e8>,
#  '액/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0e48>,
#  '야/Eomi': <gensim.models.keyedvectors.Vocab at 0x130d0ea20>,
#  '양립/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0c18>,
#  '양육/Noun': <gensim.models.keyedvectors.Vocab at 0x130c9f470>,
#  '어느/Adverb': <gensim.models.keyedvectors.Vocab at 0x1313b04e0>,
#  '억원/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0d30>,
#  '언어/Noun': <gensim.models.keyedvectors.Vocab at 0x130cf00f0>,
#  '업자/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16c50>,
#  '업체/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0ebe0>,
#  '없/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d16cf8>,
#  '없는/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d08cf8>,
#  '에/Eomi': <gensim.models.keyedvectors.Vocab at 0x1313b0eb8>,
#  '에/Josa': <gensim.models.keyedvectors.Vocab at 0x1313ac080>,
#  '에게/Josa': <gensim.models.keyedvectors.Vocab at 0x130d08f28>,
#  '에는/Josa': <gensim.models.keyedvectors.Vocab at 0x1313b2ef0>,
#  '에도/Josa': <gensim.models.keyedvectors.Vocab at 0x130c9fc88>,
#  '에서/Josa': <gensim.models.keyedvectors.Vocab at 0x1313ac898>,
#  '에서/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02588>,
#  '에서의/Josa': <gensim.models.keyedvectors.Vocab at 0x130d08240>,
#  '여/Josa': <gensim.models.keyedvectors.Vocab at 0x1313b0be0>,
#  '여/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac470>,
#  '여부/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08390>,
#  '여성가족부/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb390>,
#  '여야/Noun': <gensim.models.keyedvectors.Vocab at 0x130d659b0>,
#  '여의/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0320>,
#  '여자/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac4e0>,
#  '연/Noun': <gensim.models.keyedvectors.Vocab at 0x1313acb00>,
#  '연령/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e860>,
#  '연월일/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76f98>,
#  '연장/Noun': <gensim.models.keyedvectors.Vocab at 0x130cfea58>,
#  '연한/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02940>,
#  '연합/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65b38>,
#  '예고/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16908>,
#  '예산/Noun': <gensim.models.keyedvectors.Vocab at 0x130b7a860>,
#  '예상된/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b01d0>,
#  '예정/Noun': <gensim.models.keyedvectors.Vocab at 0x130d020f0>,
#  '와/Josa': <gensim.models.keyedvectors.Vocab at 0x130d08be0>,
#  '와/Noun': <gensim.models.keyedvectors.Vocab at 0x130d085f8>,
#  '외/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb518>,
#  '외국인/Noun': <gensim.models.keyedvectors.Vocab at 0x130d67128>,
#  '요인/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac828>,
#  '요청/Noun': <gensim.models.keyedvectors.Vocab at 0x130d650f0>,
#  '용/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08198>,
#  '우/Adverb': <gensim.models.keyedvectors.Vocab at 0x130d08630>,
#  '우리/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65d68>,
#  '운영/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65710>,
#  '원/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02390>,
#  '원/Suffix': <gensim.models.keyedvectors.Vocab at 0x1313acac8>,
#  '원사/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16be0>,
#  '월/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0ac8>,
#  '월급/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b04a8>,
#  '위/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08898>,
#  '위반하여/Verb': <gensim.models.keyedvectors.Vocab at 0x130cebef0>,
#  '위반한/Verb': <gensim.models.keyedvectors.Vocab at 0x130d16dd8>,
#  '위하여/Verb': <gensim.models.keyedvectors.Vocab at 0x130c9ce48>,
#  '위한/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08b70>,
#  '위해/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65518>,
#  '유엔/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0ef98>,
#  '유지/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16f98>,
#  '육/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08c50>,
#  '육아/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac9b0>,
#  '육아휴직/Noun': <gensim.models.keyedvectors.Vocab at 0x130c9ce80>,
#  '으로/Josa': <gensim.models.keyedvectors.Vocab at 0x1313ac2e8>,
#  '은/Josa': <gensim.models.keyedvectors.Vocab at 0x130d0ed68>,
#  '을/Eomi': <gensim.models.keyedvectors.Vocab at 0x130d0e940>,
#  '을/Josa': <gensim.models.keyedvectors.Vocab at 0x130c9ce10>,
#  '음/Eomi': <gensim.models.keyedvectors.Vocab at 0x130c79fd0>,
#  '음/Noun': <gensim.models.keyedvectors.Vocab at 0x130d084e0>,
#  '의/Josa': <gensim.models.keyedvectors.Vocab at 0x130c9fba8>,
#  '의/Noun': <gensim.models.keyedvectors.Vocab at 0x130c765f8>,
#  '의견/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16128>,
#  '의안/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0828>,
#  '의원/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76b00>,
#  '의하여/Verb': <gensim.models.keyedvectors.Vocab at 0x130d16780>,
#  '의한/Verb': <gensim.models.keyedvectors.Vocab at 0x130d16cc0>,
#  '이/Determiner': <gensim.models.keyedvectors.Vocab at 0x1313b0da0>,
#  '이/Eomi': <gensim.models.keyedvectors.Vocab at 0x130c9fcc0>,
#  '이/Josa': <gensim.models.keyedvectors.Vocab at 0x130c9f9e8>,
#  '이/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b2cc0>,
#  '이기/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02748>,
#  '이나/Josa': <gensim.models.keyedvectors.Vocab at 0x130c9fb00>,
#  '이내/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08c18>,
#  '이다/Josa': <gensim.models.keyedvectors.Vocab at 0x130d08eb8>,
#  '이라/Verb': <gensim.models.keyedvectors.Vocab at 0x130d02fd0>,
#  '이러한/Adjective': <gensim.models.keyedvectors.Vocab at 0x1313b0c88>,
#  '이를/Verb': <gensim.models.keyedvectors.Vocab at 0x130d02eb8>,
#  '이며/Josa': <gensim.models.keyedvectors.Vocab at 0x130d02978>,
#  '이상/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08d68>,
#  '이용/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02a20>,
#  '이용자/Noun': <gensim.models.keyedvectors.Vocab at 0x130cf0940>,
#  '이유/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76cf8>,
#  '이하/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0eb38>,
#  '이해/Noun': <gensim.models.keyedvectors.Vocab at 0x10f0f6a58>,
#  '이후/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65208>,
#  '인/Josa': <gensim.models.keyedvectors.Vocab at 0x130d0ee48>,
#  '인/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76a90>,
#  '인건비/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08f60>,
#  '인력/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08208>,
#  '인원/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02240>,
#  '인정/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16f60>,
#  '인정되는/Verb': <gensim.models.keyedvectors.Vocab at 0x130d652b0>,
#  '인하여/Verb': <gensim.models.keyedvectors.Vocab at 0x130d16c88>,
#  '일/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0e10>,
#  '일반/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02780>,
#  '일부/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76a20>,
#  '임/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08278>,
#  '임무/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65c88>,
#  '임용/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac160>,
#  '입법/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16978>,
#  '있/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d0e978>,
#  '있는/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d0e390>,
#  '있다/Adjective': <gensim.models.keyedvectors.Vocab at 0x1313ac240>,
#  '있도/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d08f98>,
#  '있어/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d0eb70>,
#  '있으/Adjective': <gensim.models.keyedvectors.Vocab at 0x1313b0860>,
#  '자/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76e48>,
#  '자/Suffix': <gensim.models.keyedvectors.Vocab at 0x1313b0588>,
#  '자녀/Noun': <gensim.models.keyedvectors.Vocab at 0x130c9f6a0>,
#  '자는/Verb': <gensim.models.keyedvectors.Vocab at 0x1313ac1d0>,
#  '자료/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02f28>,
#  '자본금/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb160>,
#  '작성/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02470>,
#  '작성자/Noun': <gensim.models.keyedvectors.Vocab at 0x130bad748>,
#  '작전/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65748>,
#  '장/Noun': <gensim.models.keyedvectors.Vocab at 0x130bad710>,
#  '장/Suffix': <gensim.models.keyedvectors.Vocab at 0x130d65278>,
#  '장관/Noun': <gensim.models.keyedvectors.Vocab at 0x130d656a0>,
#  '재/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16518>,
#  '재원/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e320>,
#  '재정/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac7b8>,
#  '저학년/Noun': <gensim.models.keyedvectors.Vocab at 0x130c9f4a8>,
#  '적/Suffix': <gensim.models.keyedvectors.Vocab at 0x1313b0cf8>,
#  '전/Noun': <gensim.models.keyedvectors.Vocab at 0x130b422b0>,
#  '전부/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65cf8>,
#  '절차/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16748>,
#  '점검/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65780>,
#  '정/Noun': <gensim.models.keyedvectors.Vocab at 0x130c91d68>,
#  '정보/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16fd0>,
#  '정부/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65160>,
#  '정의/Noun': <gensim.models.keyedvectors.Vocab at 0x130d087f0>,
#  '정의화/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76a58>,
#  '정책/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16828>,
#  '정하는/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08e10>,
#  '정한/Verb': <gensim.models.keyedvectors.Vocab at 0x130d16630>,
#  '제/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e710>,
#  '제공하여/Verb': <gensim.models.keyedvectors.Vocab at 0x130d0ec18>,
#  '제도/Noun': <gensim.models.keyedvectors.Vocab at 0x130d080b8>,
#  '제안/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76e10>,
#  '조/Noun': <gensim.models.keyedvectors.Vocab at 0x130c91b00>,
#  '조의/Noun': <gensim.models.keyedvectors.Vocab at 0x130b6cac8>,
#  '조정/Noun': <gensim.models.keyedvectors.Vocab at 0x130d67240>,
#  '조정함/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b0f60>,
#  '조제/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e5f8>,
#  '조치/Noun': <gensim.models.keyedvectors.Vocab at 0x130d657f0>,
#  '주/PreEomi': <gensim.models.keyedvectors.Vocab at 0x130d02860>,
#  '주요/Noun': <gensim.models.keyedvectors.Vocab at 0x130c76ef0>,
#  '주지/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02518>,
#  '중/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e208>,
#  '중개/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0eba8>,
#  '중개업/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0ea90>,
#  '중인/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b2eb8>,
#  '지/Eomi': <gensim.models.keyedvectors.Vocab at 0x130cfee80>,
#  '지/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08a58>,
#  '지급/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0240>,
#  '지급하는/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08160>,
#  '지급하던/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08cc0>,
#  '지급해야/Verb': <gensim.models.keyedvectors.Vocab at 0x130d027f0>,
#  '지방/Noun': <gensim.models.keyedvectors.Vocab at 0x1313aca20>,
#  '지역/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65dd8>,
#  '지원/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0a58>,
#  '지휘/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65978>,
#  '직접/Noun': <gensim.models.keyedvectors.Vocab at 0x130d162b0>,
#  '징역/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb198>,
#  '차/Noun': <gensim.models.keyedvectors.Vocab at 0x130d086a0>,
#  '차이/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02cf8>,
#  '참여/Noun': <gensim.models.keyedvectors.Vocab at 0x130d165f8>,
#  '처/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16ef0>,
#  '처분/Noun': <gensim.models.keyedvectors.Vocab at 0x10f0f6ef0>,
#  '척/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0ec50>,
#  '천만원/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16ac8>,
#  '첨부/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac780>,
#  '초등학교/Noun': <gensim.models.keyedvectors.Vocab at 0x130c9f6d8>,
#  '총/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b07f0>,
#  '추가/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b07b8>,
#  '추계/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac6d8>,
#  '추정/Noun': <gensim.models.keyedvectors.Vocab at 0x130d023c8>,
#  '추진/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0cc0>,
#  '출/Verb': <gensim.models.keyedvectors.Vocab at 0x130d65e48>,
#  '출산/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e9b0>,
#  '출입국관리/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb320>,
#  '취학/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e0b8>,
#  '칙/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b2e48>,
#  '크/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08780>,
#  '통계/Noun': <gensim.models.keyedvectors.Vocab at 0x130d026a0>,
#  '통보/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb358>,
#  '특/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65a20>,
#  '특별한/Adjective': <gensim.models.keyedvectors.Vocab at 0x1313ac358>,
#  '특수전/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65ba8>,
#  '팀/Noun': <gensim.models.keyedvectors.Vocab at 0x130bad6d8>,
#  '파견/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65e80>,
#  '평가/Noun': <gensim.models.keyedvectors.Vocab at 0x130d166d8>,
#  '평균/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0518>,
#  '평등/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0908>,
#  '평화/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e4a8>,
#  '폐업/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb048>,
#  '포함/Noun': <gensim.models.keyedvectors.Vocab at 0x130cebf98>,
#  '표/Noun': <gensim.models.keyedvectors.Vocab at 0x130c91c88>,
#  '필요/Noun': <gensim.models.keyedvectors.Vocab at 0x130c9fda0>,
#  '필요하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d16198>,
#  '필요한/Adjective': <gensim.models.keyedvectors.Vocab at 0x130d16550>,
#  '하/PreEomi': <gensim.models.keyedvectors.Vocab at 0x130d02b38>,
#  '하거/Verb': <gensim.models.keyedvectors.Vocab at 0x130d08e80>,
#  '하게/Verb': <gensim.models.keyedvectors.Vocab at 0x1313ac550>,
#  '하고/Josa': <gensim.models.keyedvectors.Vocab at 0x1313b09e8>,
#  '하고/Verb': <gensim.models.keyedvectors.Vocab at 0x130d0ecc0>,
#  '하기/Verb': <gensim.models.keyedvectors.Vocab at 0x130c9cd68>,
#  '하나/Noun': <gensim.models.keyedvectors.Vocab at 0x1313ac048>,
#  '하는/Verb': <gensim.models.keyedvectors.Vocab at 0x1313ac320>,
#  '하더/Verb': <gensim.models.keyedvectors.Vocab at 0x130d027b8>,
#  '하도/Verb': <gensim.models.keyedvectors.Vocab at 0x130d02080>,
#  '하도급/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16940>,
#  '하려/Verb': <gensim.models.keyedvectors.Vocab at 0x130d0e8d0>,
#  '하며/Verb': <gensim.models.keyedvectors.Vocab at 0x130d657b8>,
#  '하여/Verb': <gensim.models.keyedvectors.Vocab at 0x1313ac400>,
#  '하지/Verb': <gensim.models.keyedvectors.Vocab at 0x1313b00f0>,
#  '학년/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b2f28>,
#  '학사/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02278>,
#  '학위/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02f98>,
#  '한/Eomi': <gensim.models.keyedvectors.Vocab at 0x130d16358>,
#  '한/Josa': <gensim.models.keyedvectors.Vocab at 0x130c91550>,
#  '한/Verb': <gensim.models.keyedvectors.Vocab at 0x130c9fd68>,
#  '한국/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65908>,
#  '할/Verb': <gensim.models.keyedvectors.Vocab at 0x130c9cdd8>,
#  '함/Noun': <gensim.models.keyedvectors.Vocab at 0x10f2e5a90>,
#  '합/Noun': <gensim.models.keyedvectors.Vocab at 0x130d655f8>,
#  '항/Noun': <gensim.models.keyedvectors.Vocab at 0x126a63128>,
#  '항의/Noun': <gensim.models.keyedvectors.Vocab at 0x10f1b1828>,
#  '항제/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e518>,
#  '해/Noun': <gensim.models.keyedvectors.Vocab at 0x130d169e8>,
#  '해당/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0ea58>,
#  '해당하는/Verb': <gensim.models.keyedvectors.Vocab at 0x1313ac0b8>,
#  '해역/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e198>,
#  '행/Noun': <gensim.models.keyedvectors.Vocab at 0x130c91c50>,
#  '행위/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16d30>,
#  '행정/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16898>,
#  '행정안전부/Noun': <gensim.models.keyedvectors.Vocab at 0x130d02c50>,
#  '행정청/Noun': <gensim.models.keyedvectors.Vocab at 0x130d161d0>,
#  '행하는/Verb': <gensim.models.keyedvectors.Vocab at 0x130d673c8>,
#  '헌법/Noun': <gensim.models.keyedvectors.Vocab at 0x130d651d0>,
#  '현/Noun': <gensim.models.keyedvectors.Vocab at 0x130c91a20>,
#  '현재/Noun': <gensim.models.keyedvectors.Vocab at 0x130c9fd30>,
#  '현지/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65198>,
#  '현행/Noun': <gensim.models.keyedvectors.Vocab at 0x130c79ef0>,
#  '현행법/Noun': <gensim.models.keyedvectors.Vocab at 0x1313b0780>,
#  '현황/Noun': <gensim.models.keyedvectors.Vocab at 0x130d021d0>,
#  '협력/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65c18>,
#  '협의/Noun': <gensim.models.keyedvectors.Vocab at 0x130d16588>,
#  '호/Noun': <gensim.models.keyedvectors.Vocab at 0x130c766d8>,
#  '호의/Noun': <gensim.models.keyedvectors.Vocab at 0x130d65fd0>,
#  '화/Suffix': <gensim.models.keyedvectors.Vocab at 0x130d16a90>,
#  '확대/Noun': <gensim.models.keyedvectors.Vocab at 0x130d089e8>,
#  '확률/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08860>,
#  '확인/Noun': <gensim.models.keyedvectors.Vocab at 0x130d655c0>,
#  '활동/Noun': <gensim.models.keyedvectors.Vocab at 0x130d0e160>,
#  '후/Noun': <gensim.models.keyedvectors.Vocab at 0x130d08ef0>,
#  '훈련/Noun': <gensim.models.keyedvectors.Vocab at 0x130d67278>,
#  '휴업/Noun': <gensim.models.keyedvectors.Vocab at 0x130ceb5c0>,
#  '휴직/Noun': <gensim.models.keyedvectors.Vocab at 0x130c916d8>,
#  '히/Adverb': <gensim.models.keyedvectors.Vocab at 0x130d65390>,
#  '｢/Foreign': <gensim.models.keyedvectors.Vocab at 0x1313ac8d0>,
#  '｣/Foreign': <gensim.models.keyedvectors.Vocab at 0x1313ac940>}

# %% [markdown]
# ## Vectorize given word
# - The word should be inside vocabulary

# %%
wv_model[pos_tag('정부')]
# Out:
# array([[ 0.27367461,  0.03903432, -0.15697896, -0.05995852, -0.20556282,
#          0.29493096, -0.12461106, -0.03138593,  0.15012996,  0.21005824,
#          0.08833446, -0.0731115 , -0.22539723, -0.10171235,  0.1229942 ,
#          0.18205416, -0.35497862, -0.2029646 ,  0.22256052,  0.15792799,
#         -0.07422631,  0.1780657 ,  0.17028348, -0.49205971,  0.03582783,
#          0.13593818, -0.29048625, -0.09045641,  0.34968069, -0.15945823,
#         -0.21288867, -0.27096662,  0.20804042,  0.08516154,  0.23865591,
#         -0.22121084, -0.07074531,  0.29457942,  0.060423  ,  0.14972797,
#          0.25405997,  0.02219546,  0.24004619,  0.07117997,  0.03839031,
#          0.0894598 , -0.20990281, -0.0103013 ,  0.00508739,  0.12543575,
#          0.15545569, -0.04804167,  0.04111022,  0.08668339,  0.01405963,
#          0.12664959, -0.04975626, -0.09596296, -0.21169417,  0.26844141,
#          0.08644313,  0.16995083, -0.16674483,  0.08614352,  0.06905571,
#         -0.28268105,  0.11360523, -0.06289653,  0.17411987, -0.09281579,
#         -0.07810482, -0.44194442, -0.08589968, -0.21639667,  0.00560999,
#          0.21811979,  0.02099515,  0.16326073, -0.02589991,  0.03332681,
#          0.33234009,  0.08844711, -0.06524613,  0.09746305, -0.06884125,
#          0.03706188, -0.1071194 ,  0.11308472,  0.11272041,  0.09984177,
#          0.02007567,  0.10461044, -0.11878602, -0.01357455,  0.24016348,
#         -0.28261861,  0.27273062,  0.35684037,  0.15250084,  0.06130843]], dtype=float32)

# %% [markdown]
# ## (Optional) Normalize word vector
# ### `init_sims(replace=False)`
# ####  - If replace is set, forget the original vectors and only keep the normalized ones = saves lots of memory!

# %%
wv_model.init_sims(replace=True)

# %% [markdown]
# ## Save model

# %%
wv_model.save('./word2vec.model')

# %% [markdown]
# ## Load Model

# %%
wv_model = word2vec.Word2Vec.load('./word2vec.model')

# %%
wv_model.most_similar(pos_tag('정부'))
# Out:
# [('에/Josa', 0.9998910427093506),
#  ('의/Josa', 0.9998859167098999),
#  (':/Punctuation', 0.9998825788497925),
#  ('을/Josa', 0.9998807907104492),
#  ('를/Josa', 0.9998788833618164),
#  ('파견/Noun', 0.9998785257339478),
#  ('으로/Josa', 0.9998762607574463),
#  ('협력/Noun', 0.999875545501709),
#  ('하고/Josa', 0.9998754858970642),
#  ('은/Josa', 0.9998748898506165)]

# %%
wv_model.most_similar(pos_tag('초등학교'))
# Out:
# [('을/Josa', 0.9998282194137573),
#  ('로/Josa', 0.9998196363449097),
#  ('및/Noun', 0.9998160004615784),
#  ('의/Josa', 0.9998142719268799),
#  ('에서/Josa', 0.9998104572296143),
#  ('파견/Noun', 0.9998080730438232),
#  ('UAE/Alpha', 0.9998021721839905),
#  ('부대/Noun', 0.9998019933700562),
#  ('가/Verb', 0.9998016953468323),
#  ('를/Josa', 0.999801516532898)]

# %% [markdown]
# # Hmm.. We need to filter stop words

# %%
def pos_tag(doc):
    word_pos_list = []
    for word, pos in twitter.pos(doc):
        word_pos = word+'/'+pos
        
        if len(word) > 1 and pos == 'Noun':
            word_pos_list.append(word_pos)
            
    return word_pos_list

# %%
tokens = pos_tag(doc)

# %%
tokens
# Out:
# ['지방공무원법/Noun',
#  '일부/Noun',
#  '개정/Noun',
#  '법률/Noun',
#  '정의화/Noun',
#  '의원/Noun',
#  '대표/Noun',
#  '발의/Noun',
#  '발의/Noun',
#  '연월일/Noun',
#  '정의화/Noun',
#  '이명수/Noun',
#  '김을동/Noun',
#  '이사철/Noun',
#  '여상규/Noun',
#  '안규백/Noun',
#  '황영철/Noun',
#  '박영아/Noun',
#  '김정훈/Noun',
#  '김학송/Noun',
#  '의원/Noun',
#  '제안/Noun',
#  '이유/Noun',
#  '주요/Noun',
#  '내용/Noun',
#  '초등학교/Noun',
#  '저학년/Noun',
#  '경우/Noun',
#  '부모/Noun',
#  '사랑/Noun',
#  '필요/Noun',
#  '나이/Noun',
#  '현재/Noun',
#  '공무원/Noun',
#  '자녀/Noun',
#  '양육/Noun',
#  '육아휴직/Noun',
#  '자녀/Noun',
#  '나이/Noun',
#  '이하/Noun',
#  '초등학교/Noun',
#  '저학년/Noun',
#  '자녀/Noun',
#  '해당/Noun',
#  '부모님/Noun',
#  '일자리/Noun',
#  '출산/Noun',
#  '의욕/Noun',
#  '저하/Noun',
#  '문제/Noun',
#  '것임/Noun',
#  '따라서/Noun',
#  '육아휴직/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '이하/Noun',
#  '개정/Noun',
#  '것임/Noun',
#  '조제/Noun',
#  '항제/Noun',
#  '법률/Noun',
#  '지방공무원법/Noun',
#  '일부/Noun',
#  '개정/Noun',
#  '법률/Noun',
#  '지방공무원법/Noun',
#  '일부/Noun',
#  '다음/Noun',
#  '개정/Noun',
#  '조제/Noun',
#  '항제/Noun',
#  '이하/Noun',
#  '초등학교/Noun',
#  '취학/Noun',
#  '자녀/Noun',
#  '이하/Noun',
#  '취학/Noun',
#  '중인/Noun',
#  '경우/Noun',
#  '초등학교/Noun',
#  '학년/Noun',
#  '이하/Noun',
#  '자녀/Noun',
#  '공포/Noun',
#  '시행/Noun',
#  '구조/Noun',
#  '문대비/Noun',
#  '휴직/Noun',
#  '휴직/Noun',
#  '현행/Noun',
#  '공무원/Noun',
#  '다음/Noun',
#  '호의/Noun',
#  '하나/Noun',
#  '사유/Noun',
#  '임용/Noun',
#  '휴직/Noun',
#  '다만/Noun',
#  '경우/Noun',
#  '대통령령/Noun',
#  '사정/Noun',
#  '현행/Noun',
#  '이하/Noun',
#  '초등학교/Noun',
#  '이하/Noun',
#  '취학/Noun',
#  '중인/Noun',
#  '경우/Noun',
#  '자녀/Noun',
#  '양육/Noun',
#  '위하/Noun',
#  '초등학교/Noun',
#  '학년/Noun',
#  '이하/Noun',
#  '여자/Noun',
#  '공무원/Noun',
#  '자녀/Noun',
#  '임신/Noun',
#  '출산/Noun',
#  '현행/Noun',
#  '현행/Noun',
#  '지방공무원법/Noun',
#  '일부/Noun',
#  '개정/Noun',
#  '법률/Noun',
#  '비용/Noun',
#  '추계/Noun',
#  '첨부/Noun',
#  '사유/Noun',
#  '재정/Noun',
#  '수반/Noun',
#  '요인/Noun',
#  '개정안/Noun',
#  '국가공무원/Noun',
#  '조제/Noun',
#  '항제/Noun',
#  '국가공무원/Noun',
#  '육아/Noun',
#  '휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '이하/Noun',
#  '이하/Noun',
#  '지방/Noun',
#  '조제/Noun',
#  '항제/Noun',
#  '지방/Noun',
#  '공무원/Noun',
#  '육아휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '이하/Noun',
#  '이하/Noun',
#  '교육/Noun',
#  '공무원/Noun',
#  '조제/Noun',
#  '교육/Noun',
#  '공무원/Noun',
#  '육아휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '이하/Noun',
#  '이하/Noun',
#  '남녀/Noun',
#  '고용/Noun',
#  '평등/Noun',
#  '가정/Noun',
#  '양립/Noun',
#  '지원/Noun',
#  '법률/Noun',
#  '조제/Noun',
#  '근로자/Noun',
#  '육아휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '이하/Noun',
#  '이하/Noun',
#  '추가/Noun',
#  '재정/Noun',
#  '소요/Noun',
#  '첨부/Noun',
#  '근거/Noun',
#  '규정/Noun',
#  '의안/Noun',
#  '비용/Noun',
#  '추계/Noun',
#  '규칙/Noun',
#  '조제/Noun',
#  '단서/Noun',
#  '비용/Noun',
#  '평균/Noun',
#  '억원/Noun',
#  '미만/Noun',
#  '거나/Noun',
#  '한시/Noun',
#  '경비/Noun',
#  '로서/Noun',
#  '억원/Noun',
#  '미만/Noun',
#  '경우/Noun',
#  '첨부/Noun',
#  '사유/Noun',
#  '개정안/Noun',
#  '국가/Noun',
#  '지방/Noun',
#  '교육/Noun',
#  '공무원/Noun',
#  '근로자/Noun',
#  '육아휴직/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '이하/Noun',
#  '이하/Noun',
#  '상향/Noun',
#  '추가/Noun',
#  '재정/Noun',
#  '소요/Noun',
#  '법률/Noun',
#  '개정안/Noun',
#  '시행/Noun',
#  '가정/Noun',
#  '경우/Noun',
#  '현재/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '세이/Noun',
#  '육아휴직/Noun',
#  '신청/Noun',
#  '국가/Noun',
#  '지방/Noun',
#  '교육/Noun',
#  '공무원/Noun',
#  '근로자/Noun',
#  '대상/Noun',
#  '대상/Noun',
#  '연령/Noun',
#  '육아휴직/Noun',
#  '신청/Noun',
#  '수가/Noun',
#  '정도/Noun',
#  '경우/Noun',
#  '비용/Noun',
#  '현행법/Noun',
#  '만원/Noun',
#  '이나/Noun',
#  '현재/Noun',
#  '관련/Noun',
#  '법령/Noun',
#  '개정/Noun',
#  '추진/Noun',
#  '육아휴직/Noun',
#  '지급/Noun',
#  '월급/Noun',
#  '비례/Noun',
#  '육아휴직/Noun',
#  '여가/Noun',
#  '지급/Noun',
#  '때문/Noun',
#  '법령/Noun',
#  '개정/Noun',
#  '가정/Noun',
#  '추계/Noun',
#  '경우/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '육아휴직/Noun',
#  '지급/Noun',
#  '월급/Noun',
#  '여의/Noun',
#  '육아휴직/Noun',
#  '경우/Noun',
#  '비용/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '인건비/Noun',
#  '육아휴직/Noun',
#  '월급/Noun',
#  '육아휴직/Noun',
#  '임금/Noun',
#  '이상/Noun',
#  '따라서/Noun',
#  '실제/Noun',
#  '비용/Noun',
#  '휴직/Noun',
#  '급여/Noun',
#  '연령/Noun',
#  '확대/Noun',
#  '비용/Noun',
#  '육아휴직/Noun',
#  '월급/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '인건비/Noun',
#  '추가/Noun',
#  '재정/Noun',
#  '소요/Noun',
#  '추가/Noun',
#  '비용/Noun',
#  '발생/Noun',
#  '여부/Noun',
#  '비용/Noun',
#  '대한/Noun',
#  '수리/Noun',
#  '비용/Noun',
#  '발생/Noun',
#  '여부/Noun',
#  '하자/Noun',
#  '모델/Noun',
#  '변수/Noun',
#  '다음/Noun',
#  '정의/Noun',
#  '발생/Noun',
#  '비용/Noun',
#  '육아휴직/Noun',
#  '육아휴직/Noun',
#  '대상자/Noun',
#  '육아휴직/Noun',
#  '대상자/Noun',
#  '월급/Noun',
#  '육아휴직/Noun',
#  '경우/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '확률/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '인력/Noun',
#  '월급/Noun',
#  '수식/Noun',
#  '육아휴직/Noun',
#  '육아휴직/Noun',
#  '월급/Noun',
#  '까지/Noun',
#  '예정/Noun',
#  '육아휴직/Noun',
#  '육아휴직/Noun',
#  '경우/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '확률/Noun',
#  '고용노동부/Noun',
#  '육아휴직/Noun',
#  '관련/Noun',
#  '자료/Noun',
#  '이용/Noun',
#  '고용노동부/Noun',
#  '경우/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '대상자/Noun',
#  '육아휴직/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '예상/Noun',
#  '인원/Noun',
#  '현황/Noun',
#  '다음/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '수급/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '현황/Noun',
#  '단위/Noun',
#  '평균/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '수급/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '채용/Noun',
#  '자료/Noun',
#  '고용노동부/Noun',
#  '자료/Noun',
#  '바탕/Noun',
#  '국회예산정책처/Noun',
#  '작성/Noun',
#  '자료/Noun',
#  '육아휴직/Noun',
#  '경우/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '확률/Noun',
#  '가정/Noun',
#  '비용/Noun',
#  '가정/Noun',
#  '수식/Noun',
#  '다시/Noun',
#  '다음/Noun',
#  '수식/Noun',
#  '육아휴직/Noun',
#  '수식/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '대입/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '인력/Noun',
#  '급여/Noun',
#  '추정/Noun',
#  '육아휴직/Noun',
#  '가정/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '인력/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '이상/Noun',
#  '추가/Noun',
#  '비용/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '인력/Noun',
#  '육아휴직/Noun',
#  '월급/Noun',
#  '주지/Noun',
#  '여배/Noun',
#  '이상/Noun',
#  '월급/Noun',
#  '주지/Noun',
#  '이기/Noun',
#  '때문/Noun',
#  '추가/Noun',
#  '비용/Noun',
#  '보기/Noun',
#  '수식/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '확률/Noun',
#  '가정/Noun',
#  '경우/Noun',
#  '만원/Noun',
#  '육아휴직/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '만원/Noun',
#  '이상/Noun',
#  '추가/Noun',
#  '비용/Noun',
#  '행정안전부/Noun',
#  '통계/Noun',
#  '자료/Noun',
#  '행정안전부/Noun',
#  '통계/Noun',
#  '연감/Noun',
#  '지방/Noun',
#  '공무원/Noun',
#  '휴직/Noun',
#  '현황/Noun',
#  '자료/Noun',
#  '여기/Noun',
#  '육아휴직/Noun',
#  '경우/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '주로/Noun',
#  '임용/Noun',
#  '기자/Noun',
#  '일용직/Noun',
#  '따라서/Noun',
#  '공무원/Noun',
#  '경우/Noun',
#  '에서/Noun',
#  '일반/Noun',
#  '기업체/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '확률/Noun',
#  '차이/Noun',
#  '이상/Noun',
#  '논의/Noun',
#  '바탕/Noun',
#  '육아휴직/Noun',
#  '기간/Noun',
#  '에서/Noun',
#  '세로/Noun',
#  '연장/Noun',
#  '법률/Noun',
#  '개정/Noun',
#  '추가/Noun',
#  '비용/Noun',
#  '작성자/Noun',
#  '국회예산정책처/Noun',
#  '법안/Noun',
#  '비용/Noun',
#  '추계/Noun',
#  '예산/Noun',
#  '분석관/Noun',
#  '국가공무원/Noun',
#  '일부/Noun',
#  '개정/Noun',
#  '법률/Noun',
#  '정의화/Noun',
#  '의원/Noun',
#  '대표/Noun',
#  '발의/Noun',
#  '발의/Noun',
#  '연월일/Noun',
#  '정의화/Noun',
#  '이명수/Noun',
#  '김을동/Noun',
#  '이사철/Noun',
#  '여상규/Noun',
#  '안규백/Noun',
#  '황영철/Noun',
#  '박영아/Noun',
#  '김정훈/Noun',
#  '김학송/Noun',
#  '의원/Noun',
#  '제안/Noun',
#  '이유/Noun',
#  '주요/Noun',
#  '내용/Noun',
#  '초등학교/Noun',
#  '저학년/Noun',
#  '경우/Noun',
#  '부모/Noun',
#  '사랑/Noun',
#  '필요/Noun',
#  '나이/Noun',
#  '현재/Noun',
#  '공무원/Noun',
#  '자녀/Noun',
#  '양육/Noun',
#  '육아휴직/Noun',
#  '자녀/Noun',
#  '나이/Noun',
#  '이하/Noun',
#  '초등학교/Noun',
#  '저학년/Noun',
#  '자녀/Noun',
#  '해당/Noun',
#  '부모님/Noun',
#  '일자리/Noun',
#  '출산/Noun',
#  '의욕/Noun',
#  '저하/Noun',
#  '문제/Noun',
#  '것임/Noun',
#  '따라서/Noun',
#  '육아휴직/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '이하/Noun',
#  '개정/Noun',
#  '것임/Noun',
#  '조제/Noun',
#  '항제/Noun',
#  '법률/Noun',
#  '국가공무원/Noun',
#  '일부/Noun',
#  '개정/Noun',
#  '법률/Noun',
#  '국가공무원/Noun',
#  '일부/Noun',
#  '다음/Noun',
#  '개정/Noun',
#  '조제/Noun',
#  '항제/Noun',
#  '이하/Noun',
#  '초등학교/Noun',
#  '취학/Noun',
#  '자녀/Noun',
#  '이하/Noun',
#  '취학/Noun',
#  '중인/Noun',
#  '경우/Noun',
#  '초등학교/Noun',
#  '학년/Noun',
#  '이하/Noun',
#  '자녀/Noun',
#  '공포/Noun',
#  '시행/Noun',
#  '구조/Noun',
#  '문대비/Noun',
#  '휴직/Noun',
#  '휴직/Noun',
#  '현행/Noun',
#  '임용/Noun',
#  '공무원/Noun',
#  '다음/Noun',
#  '호의/Noun',
#  '하나/Noun',
#  '사유/Noun',
#  '휴직/Noun',
#  '휴직/Noun',
#  '다만/Noun',
#  '호의/Noun',
#  '경우/Noun',
#  '대통령령/Noun',
#  '사정/Noun',
#  '휴직/Noun',
#  '현행/Noun',
#  '이하/Noun',
#  '초등학교/Noun',
#  '이하/Noun',
#  '취학/Noun',
#  '중인/Noun',
#  '경우/Noun',
#  '자녀/Noun',
#  '양육/Noun',
#  '위하/Noun',
#  '초등학교/Noun',
#  '학년/Noun',
#  '이하/Noun',
#  '여자/Noun',
#  '공무원/Noun',
#  '자녀/Noun',
#  '임신/Noun',
#  '출산/Noun',
#  '현행/Noun',
#  '현행/Noun',
#  '국가공무원/Noun',
#  '일부/Noun',
#  '개정/Noun',
#  '법률/Noun',
#  '비용/Noun',
#  '추계/Noun',
#  '첨부/Noun',
#  '사유/Noun',
#  '재정/Noun',
#  '수반/Noun',
#  '요인/Noun',
#  '개정안/Noun',
#  '국가공무원/Noun',
#  '조제/Noun',
#  '항제/Noun',
#  '국가공무원/Noun',
#  '육아/Noun',
#  '휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '이하/Noun',
#  '이하/Noun',
#  '지방/Noun',
#  '조제/Noun',
#  '항제/Noun',
#  '지방/Noun',
#  '공무원/Noun',
#  '육아휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '이하/Noun',
#  '이하/Noun',
#  '교육/Noun',
#  '공무원/Noun',
#  '조제/Noun',
#  '교육/Noun',
#  '공무원/Noun',
#  '육아휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '이하/Noun',
#  '이하/Noun',
#  '남녀/Noun',
#  '고용/Noun',
#  '평등/Noun',
#  '가정/Noun',
#  '양립/Noun',
#  '지원/Noun',
#  '법률/Noun',
#  '조제/Noun',
#  '근로자/Noun',
#  '육아휴직/Noun',
#  '가능/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '이하/Noun',
#  '이하/Noun',
#  '추가/Noun',
#  '재정/Noun',
#  '소요/Noun',
#  '첨부/Noun',
#  '근거/Noun',
#  '규정/Noun',
#  '의안/Noun',
#  '비용/Noun',
#  '추계/Noun',
#  '규칙/Noun',
#  '조제/Noun',
#  '단서/Noun',
#  '비용/Noun',
#  '평균/Noun',
#  '억원/Noun',
#  '미만/Noun',
#  '거나/Noun',
#  '한시/Noun',
#  '경비/Noun',
#  '로서/Noun',
#  '억원/Noun',
#  '미만/Noun',
#  '경우/Noun',
#  '첨부/Noun',
#  '사유/Noun',
#  '개정안/Noun',
#  '국가/Noun',
#  '지방/Noun',
#  '교육/Noun',
#  '공무원/Noun',
#  '근로자/Noun',
#  '육아휴직/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '이하/Noun',
#  '이하/Noun',
#  '상향/Noun',
#  '추가/Noun',
#  '재정/Noun',
#  '소요/Noun',
#  '법률/Noun',
#  '개정안/Noun',
#  '시행/Noun',
#  '가정/Noun',
#  '경우/Noun',
#  '현재/Noun',
#  '자녀/Noun',
#  '연령/Noun',
#  '세이/Noun',
#  '육아휴직/Noun',
#  '신청/Noun',
#  '국가/Noun',
#  '지방/Noun',
#  '교육/Noun',
#  '공무원/Noun',
#  '근로자/Noun',
#  '대상/Noun',
#  '대상/Noun',
#  '연령/Noun',
#  '육아휴직/Noun',
#  '신청/Noun',
#  '수가/Noun',
#  '정도/Noun',
#  '경우/Noun',
#  '비용/Noun',
#  '현행법/Noun',
#  '만원/Noun',
#  '이나/Noun',
#  '현재/Noun',
#  '관련/Noun',
#  '법령/Noun',
#  '개정/Noun',
#  '추진/Noun',
#  '육아휴직/Noun',
#  '지급/Noun',
#  '월급/Noun',
#  '비례/Noun',
#  '육아휴직/Noun',
#  '여가/Noun',
#  '지급/Noun',
#  '때문/Noun',
#  '법령/Noun',
#  '개정/Noun',
#  '가정/Noun',
#  '추계/Noun',
#  '경우/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '육아휴직/Noun',
#  '지급/Noun',
#  '월급/Noun',
#  '여의/Noun',
#  '육아휴직/Noun',
#  '경우/Noun',
#  '비용/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '인건비/Noun',
#  '육아휴직/Noun',
#  '월급/Noun',
#  '육아휴직/Noun',
#  '임금/Noun',
#  '이상/Noun',
#  '따라서/Noun',
#  '실제/Noun',
#  '비용/Noun',
#  '휴직/Noun',
#  '급여/Noun',
#  '연령/Noun',
#  '확대/Noun',
#  '비용/Noun',
#  '육아휴직/Noun',
#  '월급/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '인건비/Noun',
#  '추가/Noun',
#  '재정/Noun',
#  '소요/Noun',
#  '추가/Noun',
#  '비용/Noun',
#  '발생/Noun',
#  '여부/Noun',
#  '비용/Noun',
#  '대한/Noun',
#  '수리/Noun',
#  '비용/Noun',
#  '발생/Noun',
#  '여부/Noun',
#  '하자/Noun',
#  '모델/Noun',
#  '변수/Noun',
#  '다음/Noun',
#  '정의/Noun',
#  '발생/Noun',
#  '비용/Noun',
#  '육아휴직/Noun',
#  '육아휴직/Noun',
#  '대상자/Noun',
#  '육아휴직/Noun',
#  '대상자/Noun',
#  '월급/Noun',
#  '육아휴직/Noun',
#  '경우/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '확률/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '인력/Noun',
#  '월급/Noun',
#  '수식/Noun',
#  '육아휴직/Noun',
#  '육아휴직/Noun',
#  '월급/Noun',
#  '까지/Noun',
#  '예정/Noun',
#  '육아휴직/Noun',
#  '육아휴직/Noun',
#  '경우/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '확률/Noun',
#  '고용노동부/Noun',
#  '육아휴직/Noun',
#  '관련/Noun',
#  '자료/Noun',
#  '이용/Noun',
#  '고용노동부/Noun',
#  '경우/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '대상자/Noun',
#  '육아휴직/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '예상/Noun',
#  '인원/Noun',
#  '현황/Noun',
#  '다음/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '수급/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '현황/Noun',
#  '단위/Noun',
#  '평균/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '수급/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '채용/Noun',
#  '자료/Noun',
#  '고용노동부/Noun',
#  '자료/Noun',
#  '바탕/Noun',
#  '국회예산정책처/Noun',
#  '작성/Noun',
#  '자료/Noun',
#  '육아휴직/Noun',
#  '경우/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '확률/Noun',
#  '가정/Noun',
#  '비용/Noun',
#  '가정/Noun',
#  '수식/Noun',
#  '다시/Noun',
#  '다음/Noun',
#  '수식/Noun',
#  '육아휴직/Noun',
#  '수식/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '대입/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '인력/Noun',
#  '급여/Noun',
#  '추정/Noun',
#  '육아휴직/Noun',
#  '가정/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '인력/Noun',
#  '육아휴직/Noun',
#  '급여/Noun',
#  '이상/Noun',
#  '추가/Noun',
#  '비용/Noun',
#  '대체/Noun',
#  '고용/Noun',
#  '인력/Noun',
#  '육아휴직/Noun',
#  '월급/Noun',
#  '주지/Noun',
#  '여배/Noun',
#  '이상/Noun',
#  '월급/Noun',
#  '주지/Noun',
#  '이기/Noun',
#  '때문/Noun',
#  '추가/Noun',
#  '비용/Noun',
#  '보기/Noun',
#  '수식/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '확률/Noun',
#  '가정/Noun',
#  '경우/Noun',
#  '만원/Noun',
#  '육아휴직/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '만원/Noun',
#  '이상/Noun',
#  '추가/Noun',
#  '비용/Noun',
#  '행정안전부/Noun',
#  '통계/Noun',
#  '자료/Noun',
#  '행정안전부/Noun',
#  '통계/Noun',
#  '연감/Noun',
#  '지방/Noun',
#  '공무원/Noun',
#  '휴직/Noun',
#  '현황/Noun',
#  '자료/Noun',
#  '여기/Noun',
#  '육아휴직/Noun',
#  '경우/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '주로/Noun',
#  '임용/Noun',
#  '기자/Noun',
#  '일용직/Noun',
#  '따라서/Noun',
#  '공무원/Noun',
#  '경우/Noun',
#  '에서/Noun',
#  '일반/Noun',
#  '기업체/Noun',
#  '대체/Noun',
#  '인력/Noun',
#  '고용/Noun',
#  '확률/Noun',
#  '차이/Noun',
#  '이상/Noun',
#  '논의/Noun',
#  '바탕/Noun',
#  '육아휴직/Noun',
#  '기간/Noun',
#  '에서/Noun',
#  '세로/Noun',
#  '연장/Noun',
#  '법률/Noun',
#  '개정/Noun',
#  '추가/Noun',
#  '비용/Noun',
#  '작성자/Noun',
#  '국회예산정책처/Noun',
#  '법안/Noun',
#  '비용/Noun',
#  '추계/Noun',
#  '예산/Noun',
#  '분석관/Noun',
#  '교육/Noun',
#  '공무원/Noun',
#  '일부/Noun',
#  ...]

# %%
len(tokens)
# Out:
# 5650

# %%
wv_model = word2vec.Word2Vec([tokens])

# %%
wv_model.init_sims(replace=True)

# %%
wv_model.save('./word2vec.model')

# %%
wv_model.most_similar(pos_tag('정부'))
# Out:
# [('중개업/Noun', 0.9959051609039307),
#  ('결혼/Noun', 0.9957094788551331),
#  ('경우/Noun', 0.995651125907898),
#  ('파견/Noun', 0.9956295490264893),
#  ('사항/Noun', 0.9955289959907532),
#  ('중개/Noun', 0.9954251050949097),
#  ('협력/Noun', 0.9952824115753174),
#  ('조의/Noun', 0.995236873626709),
#  ('현행/Noun', 0.9951037764549255),
#  ('등록/Noun', 0.9950822591781616)]

# %%
wv_model.most_similar(pos_tag('초등학교'))
# Out:
# [('장관/Noun', 0.9828768372535706),
#  ('중개/Noun', 0.9828258752822876),
#  ('작성/Noun', 0.9827714562416077),
#  ('결혼/Noun', 0.9825571775436401),
#  ('파견/Noun', 0.9822180867195129),
#  ('현행/Noun', 0.9817008972167969),
#  ('부대/Noun', 0.9816187024116516),
#  ('작성자/Noun', 0.9812614917755127),
#  ('조의/Noun', 0.9812318086624146),
#  ('등록/Noun', 0.9811998009681702)]

# %% [markdown]
# # If you have time,
# - Try with bigger data
#     - [Sejong Corpus](https://ithub.korean.go.kr/user/corpus/corpusSearchManager.do)
#     - [KAIST Corpus](http://semanticweb.kaist.ac.kr/home/index.php/KAIST_Corpus)
#     - [Ulsan Univ. Corpus](http://nlplab.ulsan.ac.kr/doku.php?id=ucorpus)]
#     - Wikipedia Dump [[link](https://dumps.wikimedia.org/kowiki/)] [[Extractor](https://github.com/j-min/WikiExtractor_To_the_one_text)]
#     - NamuWiki Dump [[link](https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B2%A0%EC%9D%B4%EC%8A%A4%20%EB%8D%A4%ED%94%84)] [[Extractor](https://github.com/j-min/Easy-Namuwiki-Extractor)]
#
#
# - Build your own stop words
#     - https://github.com/6/stopwords-json/blob/master/dist/ko.json
#
#
# - Embedding visualization with tensorboard
#     - https://gist.github.com/lampts/026a4d6400b1efac9a13a3296f16e655
#     - http://visionigniter.blogspot.kr/2017/03/word2vec-visualization-wtensorflow.html

# %% [markdown]
# # FastText
# - https://github.com/facebookresearch/fastText
# - Python Wrapper: https://github.com/salestock/fastText.py
# - Highly optimized Word-vectorizer (Word and subword level) + Text Classifier

# %% [markdown]
# ## FastText provides a wide range of pretrained word vectors (trained in WikiPedia)
# - https://github.com/facebookresearch/fastText/blob/master/pretrained-vectors.md
#
# ## However, I prefer Kyubyong Park's pretrained word vectors (better tokenized)
# - https://github.com/Kyubyong/wordvectors

# %% [markdown]
# ### Take home (Relatively big text)
# - I used [text8](http://mattmahoney.net/dc/textdata): English wikipedia

# %%
import fasttext

# %%
# Skipgram model
model = fasttext.skipgram(
    './text8.txt', # corpus path
    'model') # output model name
print(model.words) # list of words in dictionary
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-2c7bab375540> in <module>()
#       2 model = fasttext.skipgram(
#       3     './text8.txt', # corpus path
# ----> 4     'model') # output model name
#       5 print(model.words) # list of words in dictionary
#
# fasttext/fasttext.pyx in fasttext.fasttext.skipgram (fasttext/fasttext.cpp:6453)()
#
# fasttext/fasttext.pyx in fasttext.fasttext.train_wrapper (fasttext/fasttext.cpp:5281)()
#
# ValueError: fastText: cannot load ./text8.txt

# %%
print(model['king']) # get the vector of the word 'king'

# %% [markdown]
# ## Load pretrained model

# %%
model = fasttext.load_model('model.bin')
print(model.words) # list of words in dictionary
print(model['king']) # get the vector of the word 'king'

# %% [markdown]
# ## Classifier

# %%
classifier = fasttext.supervised('data.train.txt', 'model')

# %% [markdown]
# ## Recently,  fasttext has been ported to gensim
#
# - https://radimrehurek.com/gensim/models/wrappers/fasttext.html
